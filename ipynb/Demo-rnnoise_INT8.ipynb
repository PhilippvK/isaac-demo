# %% [markdown]
# Configure notebook...

# %%
# %load_ext autoreload
# %autoreload 2
# %pwd
# Out:
# '/work/git/isaac-demo/ipynb'

# %% [markdown]
# Imports

# %%
from pathlib import Path
import datetime
import pandas as pd
from IPython.display import IFrame, HTML, Markdown, Image, display

# %% [markdown]
# Define benchmark

# %%
OUT_DIR_BASE = "../out"
BENCH = "rnnoise_INT8"
DATE = "latest"

# %% [markdown]
# Lookup directories

# %%
BENCH_DIR = Path(OUT_DIR_BASE) / BENCH
print("BENCH_DIR", BENCH_DIR)
assert BENCH_DIR.is_dir()
if DATE == "latest":
    dates = [f for f in BENCH_DIR.iterdir() if f.is_dir()]
    assert len(dates) > 0
    if len(dates) == 1:
        DATE = dates[0].name
    else:
        sorted_dates = sorted(dates, key=lambda x: datetime.datetime.strptime(x.name, "%Y%m%dT%H%M%S"))
        DATE = sorted_dates[-1].name
DATE_DIR = BENCH_DIR / DATE
assert DATE_DIR.is_dir()

print(f"Picked date: {DATE}")
print(f"Directory: {DATE_DIR}")

RUN = DATE_DIR / "run"
SESS = DATE_DIR / "sess"
WORK = DATE_DIR / "work"

PLOTS_DIR = SESS / "plots"
# Out:
# BENCH_DIR ../out/rnnoise_INT8
# Picked date: 20250130T102419
# Directory: ../out/rnnoise_INT8/20250130T102419

# %% [markdown]
# Check baseline benchmark (ISS)

# %%
REPORT = RUN / "report.csv"

COLS = ["Model", "Run Instructions", "Total ROM", "Total RAM"]
pd.read_csv(REPORT)[COLS]
# Out:
#           Model  Run Instructions  Total ROM  Total RAM
# 0  rnnoise_INT8            570178     323304       5108

# %% [markdown]
# ## Trace Analysis

# %% [markdown]
# ### Identification of Bottlenecks

# %% [markdown]
# Per basic-block

# %%
IFrame(PLOTS_DIR / "runtime_per_llvm_bb.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_llvm_bb.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per function

# %%
IFrame(PLOTS_DIR / "runtime_per_func.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_func.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per library

# %%
IFrame(PLOTS_DIR / "runtime_per_library.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_library.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per object

# %%
IFrame(PLOTS_DIR / "runtime_per_object.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_object.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Analyze instruction types

# %% [markdown]
# Per major opcode

# %%
IFrame(PLOTS_DIR / "runtime_per_opcode.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per instruction name

# %%
IFrame(PLOTS_DIR / "runtime_per_instr.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess/plots/runtime_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Choose BBs for ISE identification

# %%
CHOICES = SESS / "table" / "choices.pkl"

choices_df = pd.read_pickle(CHOICES)
choices_df
# Out:
#                                            func_name  \
# 0  tvmgen_default_fused_cast_subtract_fixed_point...
# 1  tvmgen_default_fused_cast_subtract_fixed_point...
# 2  tvmgen_default_fused_cast_subtract_fixed_point...
# 3  tvmgen_default_fused_cast_subtract_fixed_point...
# 4  tvmgen_default_fused_nn_contrib_dense_pack_add...
# 5  tvmgen_default_fused_nn_contrib_dense_pack_add...
# 6  tvmgen_default_fused_nn_contrib_dense_pack_add...
# 7  tvmgen_default_fused_nn_contrib_dense_pack_add...
#
#                                                 file bb_name  rel_weight  \
# 0  /work/git/isaac-demo/install/mlonmcu/temp/sess...   %bb.6    0.099007
# 1  /work/git/isaac-demo/install/mlonmcu/temp/sess...   %bb.8    0.099007
# 2  /work/git/isaac-demo/install/mlonmcu/temp/sess...  %bb.10    0.099007
# 3  /work/git/isaac-demo/install/mlonmcu/temp/sess...  %bb.12    0.099007
# 4  /work/git/isaac-demo/install/mlonmcu/temp/sess...   %bb.8    0.050388
# 5  /work/git/isaac-demo/install/mlonmcu/temp/sess...   %bb.6    0.050388
# 6  /work/git/isaac-demo/install/mlonmcu/temp/sess...   %bb.4    0.050388
# 7  /work/git/isaac-demo/install/mlonmcu/temp/sess...  %bb.10    0.050388
#
#    num_instrs    freq
# 0          28  2016.0
# 1          28  2016.0
# 2          28  2016.0
# 3          28  2016.0
# 4          28  1026.0
# 5          28  1026.0
# 6          28  1026.0
# 7          28  1026.0

# %%
num_choices = len(choices_df)
choices_sum_weights = choices_df["rel_weight"].sum()
max_num_instrs = choices_df["num_instrs"].max()
num_choices, choices_sum_weights, max_num_instrs
# Out:
# (8, 0.597578493741022, 28)

# %% [markdown]
# ## Identification of ISE candidates

# %% [markdown]
# ### Per Func+BB

# %% [markdown]
# Filtered candidates

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: chekc suffix?
    pie_csv = func_bb_dir / "pie.csv"
    pie_img = func_bb_dir / "pie.png"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(pie_csv))
    display(Image(pie_img))
# Out:
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.6</h2>
#                  Label  Count
# 0                  Iso     68
# 1       Filtered (I/O)     20
# 2       Filtered (Mem)     15
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.8</h2>
#                  Label  Count
# 0                  Iso     65
# 1       Filtered (I/O)     23
# 2       Filtered (Mem)     15
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.10</h2>
#                  Label  Count
# 0                  Iso     64
# 1       Filtered (I/O)     24
# 2       Filtered (Mem)     14
# 3             Selected      2
# 4  Filtered (Operands)      1
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.12</h2>
#                  Label  Count
# 0                  Iso     65
# 1       Filtered (I/O)     24
# 2       Filtered (Mem)     14
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.8</h2>
#                  Label  Count
# 0                  Iso     66
# 1       Filtered (I/O)     22
# 2       Filtered (Mem)     15
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.6</h2>
#                  Label  Count
# 0                  Iso     64
# 1       Filtered (I/O)     24
# 2       Filtered (Mem)     15
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.4</h2>
#                  Label  Count
# 0                  Iso     67
# 1       Filtered (I/O)     22
# 2       Filtered (Mem)     14
# 3  Filtered (Operands)      1
# 4             Selected      1
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.10</h2>
#                  Label  Count
# 0                  Iso     64
# 1       Filtered (I/O)     23
# 2       Filtered (Mem)     15
# 3             Selected      2
# 4  Filtered (Operands)      1

# %% [markdown]
# Generated variations

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: check suffix?
    pie2_csv = func_bb_dir / "pie2.csv"
    pie2_img = func_bb_dir / "pie2.png"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(pie2_csv))
    display(Image(pie2_img))
# Out:
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.6</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.8</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.10</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.12</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.8</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.6</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.4</h2>
#      Label  Count
# 0  Unknown    105
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.10</h2>
#      Label  Count
# 0  Unknown    105

# %% [markdown]
# Profile

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: chekc suffix?
    times_csv = func_bb_dir / "times.csv"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(times_csv))
# Out:
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.6</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000092     0.000042
# 1                    Connect to DB  0.000167     0.000076
# 2               Query func from DB  0.004774     0.002174
# 3         Query candidates from DB  0.007298     0.003323
# 4          Conversion to NX (func)  0.317615     0.144618
# 5    Conversion to NX (candidates)  0.053494     0.024357
# 6              Subgraph Generation  0.005076     0.002311
# 7                       Relabeling  0.020834     0.009486
# 8                 Dumping GF graph  0.109907     0.050043
# 9                     I/O Analysis  0.067702     0.030826
# 10                SubHash Creation  0.020818     0.009479
# 11               Isomorphism Check  0.024619     0.011209
# 12                   Overlap Check  0.007315     0.003331
# 13             Predicate Detection  0.013079     0.005955
# 14                   Schedule Subs  0.010364     0.004719
# 15             Filtering subgraphs  0.005084     0.002315
# 16            Determining IO names  0.003091     0.001408
# 17               Analyze Constants  0.002000     0.000911
# 18   Creating Constants Histograms  0.002390     0.001088
# 19            Variation generation  0.000019     0.000009
# 20               FullHash Creation  0.004338     0.001975
# 21  Filtering subgraphs (Operands)  0.002171     0.000988
# 22  Filtering subgraphs (Encoding)  0.001881     0.000856
# 23   Filtering subgraphs (Weights)  0.001833     0.000834
# 24                 Tree Generation  0.084955     0.038682
# 25                       Finish DF  0.001775     0.000808
# 26                    Apply Styles  0.002574     0.001172
# 27                 Subgraph Export  0.070132     0.031933
# 28           Dumping I/O Subgraphs  0.058614     0.026689
# 29                        Dump DFs  0.009694     0.004414
# 30                    Generate Pie  0.309662     0.140997
# 31                        Dump Pie  0.954151     0.434448
# 32               Dump Sankey chart  0.007575     0.003449
# 33                     Write Index  0.011146     0.005075
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.8</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000087     0.000042
# 1                    Connect to DB  0.000172     0.000082
# 2               Query func from DB  0.004796     0.002284
# 3         Query candidates from DB  0.007846     0.003736
# 4          Conversion to NX (func)  0.321878     0.153258
# 5    Conversion to NX (candidates)  0.054031     0.025726
# 6              Subgraph Generation  0.005493     0.002615
# 7                       Relabeling  0.021046     0.010021
# 8                 Dumping GF graph  0.105037     0.050012
# 9                     I/O Analysis  0.067709     0.032239
# 10                SubHash Creation  0.020775     0.009892
# 11               Isomorphism Check  0.023942     0.011400
# 12                   Overlap Check  0.007912     0.003767
# 13             Predicate Detection  0.013760     0.006552
# 14                   Schedule Subs  0.010739     0.005113
# 15             Filtering subgraphs  0.005121     0.002438
# 16            Determining IO names  0.003001     0.001429
# 17               Analyze Constants  0.001978     0.000942
# 18   Creating Constants Histograms  0.002401     0.001143
# 19            Variation generation  0.000018     0.000009
# 20               FullHash Creation  0.004243     0.002020
# 21  Filtering subgraphs (Operands)  0.002093     0.000997
# 22  Filtering subgraphs (Encoding)  0.001837     0.000874
# 23   Filtering subgraphs (Weights)  0.001776     0.000846
# 24                 Tree Generation  0.073446     0.034970
# 25                       Finish DF  0.003271     0.001557
# 26                    Apply Styles  0.004697     0.002236
# 27                 Subgraph Export  0.048177     0.022939
# 28           Dumping I/O Subgraphs  0.087767     0.041789
# 29                        Dump DFs  0.024241     0.011542
# 30                    Generate Pie  0.316004     0.150462
# 31                        Dump Pie  0.830609     0.395485
# 32               Dump Sankey chart  0.010958     0.005218
# 33                     Write Index  0.013369     0.006365
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.10</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000086     0.000038
# 1                    Connect to DB  0.000172     0.000077
# 2               Query func from DB  0.004688     0.002089
# 3         Query candidates from DB  0.008125     0.003620
# 4          Conversion to NX (func)  0.305947     0.136319
# 5    Conversion to NX (candidates)  0.054215     0.024156
# 6              Subgraph Generation  0.005119     0.002281
# 7                       Relabeling  0.020940     0.009330
# 8                 Dumping GF graph  0.087438     0.038959
# 9                     I/O Analysis  0.069037     0.030760
# 10                SubHash Creation  0.020869     0.009299
# 11               Isomorphism Check  0.023799     0.010604
# 12                   Overlap Check  0.007855     0.003500
# 13             Predicate Detection  0.014074     0.006271
# 14                   Schedule Subs  0.011053     0.004925
# 15             Filtering subgraphs  0.005216     0.002324
# 16            Determining IO names  0.003343     0.001489
# 17               Analyze Constants  0.002062     0.000919
# 18   Creating Constants Histograms  0.003154     0.001405
# 19            Variation generation  0.000018     0.000008
# 20               FullHash Creation  0.004435     0.001976
# 21  Filtering subgraphs (Operands)  0.002193     0.000977
# 22  Filtering subgraphs (Encoding)  0.001984     0.000884
# 23   Filtering subgraphs (Weights)  0.001921     0.000856
# 24                 Tree Generation  0.128213     0.057127
# 25                       Finish DF  0.004481     0.001997
# 26                    Apply Styles  0.006301     0.002808
# 27                 Subgraph Export  0.115595     0.051505
# 28           Dumping I/O Subgraphs  0.116925     0.052098
# 29                        Dump DFs  0.009709     0.004326
# 30                    Generate Pie  0.319533     0.142373
# 31                        Dump Pie  0.869709     0.387512
# 32               Dump Sankey chart  0.005161     0.002300
# 33                     Write Index  0.010971     0.004888
# <h2>Func: tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91_, BB: %bb.12</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000087     0.000042
# 1                    Connect to DB  0.000166     0.000081
# 2               Query func from DB  0.008705     0.004259
# 3         Query candidates from DB  0.006027     0.002949
# 4          Conversion to NX (func)  0.278595     0.136309
# 5    Conversion to NX (candidates)  0.055107     0.026962
# 6              Subgraph Generation  0.005367     0.002626
# 7                       Relabeling  0.021491     0.010515
# 8                 Dumping GF graph  0.091045     0.044546
# 9                     I/O Analysis  0.068262     0.033399
# 10                SubHash Creation  0.020898     0.010225
# 11               Isomorphism Check  0.023627     0.011560
# 12                   Overlap Check  0.007683     0.003759
# 13             Predicate Detection  0.013874     0.006788
# 14                   Schedule Subs  0.010812     0.005290
# 15             Filtering subgraphs  0.005103     0.002497
# 16            Determining IO names  0.002995     0.001465
# 17               Analyze Constants  0.001984     0.000971
# 18   Creating Constants Histograms  0.002377     0.001163
# 19            Variation generation  0.000019     0.000009
# 20               FullHash Creation  0.004136     0.002023
# 21  Filtering subgraphs (Operands)  0.002106     0.001030
# 22  Filtering subgraphs (Encoding)  0.001834     0.000897
# 23   Filtering subgraphs (Weights)  0.001838     0.000899
# 24                 Tree Generation  0.074693     0.036545
# 25                       Finish DF  0.004444     0.002174
# 26                    Apply Styles  0.006399     0.003131
# 27                 Subgraph Export  0.055219     0.027017
# 28           Dumping I/O Subgraphs  0.059795     0.029256
# 29                        Dump DFs  0.009636     0.004715
# 30                    Generate Pie  0.313589     0.153431
# 31                        Dump Pie  0.862171     0.421837
# 32               Dump Sankey chart  0.010840     0.005304
# 33                     Write Index  0.012927     0.006325
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.8</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000091     0.000047
# 1                    Connect to DB  0.000170     0.000087
# 2               Query func from DB  0.004666     0.002397
# 3         Query candidates from DB  0.007094     0.003644
# 4          Conversion to NX (func)  0.171694     0.088189
# 5    Conversion to NX (candidates)  0.053930     0.027701
# 6              Subgraph Generation  0.005118     0.002629
# 7                       Relabeling  0.015107     0.007760
# 8                 Dumping GF graph  0.056588     0.029066
# 9                     I/O Analysis  0.067233     0.034534
# 10                SubHash Creation  0.020682     0.010623
# 11               Isomorphism Check  0.025462     0.013078
# 12                   Overlap Check  0.007517     0.003861
# 13             Predicate Detection  0.013285     0.006824
# 14                   Schedule Subs  0.010614     0.005452
# 15             Filtering subgraphs  0.005130     0.002635
# 16            Determining IO names  0.002993     0.001537
# 17               Analyze Constants  0.001967     0.001010
# 18   Creating Constants Histograms  0.002391     0.001228
# 19            Variation generation  0.000019     0.000010
# 20               FullHash Creation  0.004170     0.002142
# 21  Filtering subgraphs (Operands)  0.002140     0.001099
# 22  Filtering subgraphs (Encoding)  0.001823     0.000936
# 23   Filtering subgraphs (Weights)  0.001786     0.000917
# 24                 Tree Generation  0.054973     0.028237
# 25                       Finish DF  0.004651     0.002389
# 26                    Apply Styles  0.006378     0.003276
# 27                 Subgraph Export  0.074199     0.038112
# 28           Dumping I/O Subgraphs  0.057481     0.029525
# 29                        Dump DFs  0.009532     0.004896
# 30                    Generate Pie  0.313693     0.161125
# 31                        Dump Pie  0.920145     0.472623
# 32               Dump Sankey chart  0.011382     0.005846
# 33                     Write Index  0.012785     0.006567
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.6</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000089     0.000045
# 1                    Connect to DB  0.000162     0.000083
# 2               Query func from DB  0.005229     0.002682
# 3         Query candidates from DB  0.007116     0.003650
# 4          Conversion to NX (func)  0.172892     0.088679
# 5    Conversion to NX (candidates)  0.053157     0.027265
# 6              Subgraph Generation  0.005114     0.002623
# 7                       Relabeling  0.015023     0.007705
# 8                 Dumping GF graph  0.054095     0.027746
# 9                     I/O Analysis  0.069252     0.035520
# 10                SubHash Creation  0.021047     0.010795
# 11               Isomorphism Check  0.024434     0.012533
# 12                   Overlap Check  0.008121     0.004165
# 13             Predicate Detection  0.014549     0.007463
# 14                   Schedule Subs  0.010969     0.005626
# 15             Filtering subgraphs  0.005194     0.002664
# 16            Determining IO names  0.002939     0.001507
# 17               Analyze Constants  0.001956     0.001003
# 18   Creating Constants Histograms  0.002371     0.001216
# 19            Variation generation  0.000019     0.000010
# 20               FullHash Creation  0.004159     0.002133
# 21  Filtering subgraphs (Operands)  0.002118     0.001086
# 22  Filtering subgraphs (Encoding)  0.001834     0.000941
# 23   Filtering subgraphs (Weights)  0.001812     0.000929
# 24                 Tree Generation  0.054871     0.028144
# 25                       Finish DF  0.002069     0.001061
# 26                    Apply Styles  0.002361     0.001211
# 27                 Subgraph Export  0.061877     0.031737
# 28           Dumping I/O Subgraphs  0.088697     0.045494
# 29                        Dump DFs  0.010729     0.005503
# 30                    Generate Pie  0.312827     0.160453
# 31                        Dump Pie  0.907856     0.465651
# 32               Dump Sankey chart  0.011133     0.005710
# 33                     Write Index  0.013582     0.006966
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.4</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000092     0.000046
# 1                    Connect to DB  0.000166     0.000084
# 2               Query func from DB  0.004722     0.002382
# 3         Query candidates from DB  0.008102     0.004087
# 4          Conversion to NX (func)  0.199297     0.100531
# 5    Conversion to NX (candidates)  0.053996     0.027237
# 6              Subgraph Generation  0.005172     0.002609
# 7                       Relabeling  0.014974     0.007553
# 8                 Dumping GF graph  0.055289     0.027889
# 9                     I/O Analysis  0.069665     0.035141
# 10                SubHash Creation  0.021874     0.011034
# 11               Isomorphism Check  0.025184     0.012703
# 12                   Overlap Check  0.007569     0.003818
# 13             Predicate Detection  0.013958     0.007041
# 14                   Schedule Subs  0.010764     0.005430
# 15             Filtering subgraphs  0.005100     0.002573
# 16            Determining IO names  0.003108     0.001568
# 17               Analyze Constants  0.002032     0.001025
# 18   Creating Constants Histograms  0.002413     0.001217
# 19            Variation generation  0.000019     0.000010
# 20               FullHash Creation  0.004336     0.002187
# 21  Filtering subgraphs (Operands)  0.002137     0.001078
# 22  Filtering subgraphs (Encoding)  0.001904     0.000960
# 23   Filtering subgraphs (Weights)  0.001841     0.000929
# 24                 Tree Generation  0.055351     0.027921
# 25                       Finish DF  0.004955     0.002500
# 26                    Apply Styles  0.006498     0.003278
# 27                 Subgraph Export  0.068025     0.034314
# 28           Dumping I/O Subgraphs  0.096631     0.048743
# 29                        Dump DFs  0.021977     0.011086
# 30                    Generate Pie  0.318238     0.160528
# 31                        Dump Pie  0.873224     0.440478
# 32               Dump Sankey chart  0.010950     0.005524
# 33                     Write Index  0.012887     0.006501
# <h2>Func: tvmgen_default_fused_nn_contrib_dense_pack_add_fixed_point_multiply_add_clip_cast_4, BB: %bb.10</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000090     0.000042
# 1                    Connect to DB  0.000164     0.000076
# 2               Query func from DB  0.005563     0.002578
# 3         Query candidates from DB  0.008516     0.003947
# 4          Conversion to NX (func)  0.191533     0.088766
# 5    Conversion to NX (candidates)  0.053785     0.024927
# 6              Subgraph Generation  0.005098     0.002363
# 7                       Relabeling  0.014704     0.006814
# 8                 Dumping GF graph  0.054067     0.025057
# 9                     I/O Analysis  0.067591     0.031325
# 10                SubHash Creation  0.020810     0.009644
# 11               Isomorphism Check  0.023727     0.010996
# 12                   Overlap Check  0.007762     0.003597
# 13             Predicate Detection  0.014231     0.006595
# 14                   Schedule Subs  0.010936     0.005068
# 15             Filtering subgraphs  0.005205     0.002412
# 16            Determining IO names  0.003403     0.001577
# 17               Analyze Constants  0.002039     0.000945
# 18   Creating Constants Histograms  0.003058     0.001417
# 19            Variation generation  0.000018     0.000009
# 20               FullHash Creation  0.004453     0.002064
# 21  Filtering subgraphs (Operands)  0.002200     0.001020
# 22  Filtering subgraphs (Encoding)  0.001953     0.000905
# 23   Filtering subgraphs (Weights)  0.001881     0.000872
# 24                 Tree Generation  0.191612     0.088802
# 25                       Finish DF  0.004620     0.002141
# 26                    Apply Styles  0.006258     0.002900
# 27                 Subgraph Export  0.094889     0.043976
# 28           Dumping I/O Subgraphs  0.115561     0.053557
# 29                        Dump DFs  0.009621     0.004459
# 30                    Generate Pie  0.312784     0.144959
# 31                        Dump Pie  0.902340     0.418189
# 32               Dump Sankey chart  0.005828     0.002701
# 33                     Write Index  0.011437     0.005300

# %% [markdown]
# ### Combined results

# %% [markdown]
# Pairwise overlaps

# %%
overlaps_file = WORK / "overlaps.csv"
pd.read_csv(overlaps_file)
# Out:
#     x  y   nodes  size
# 0   0  1     {0}     1
# 1   0  2     {0}     1
# 2   0  3     {0}     1
# 3   0  4     {0}     1
# 4   0  5     {0}     1
# 5   0  6     {0}     1
# 6   0  7     {0}     1
# 7   1  2     {0}     1
# 8   1  3     {0}     1
# 9   1  4     {0}     1
# 10  1  5     {0}     1
# 11  1  6     {0}     1
# 12  1  7     {0}     1
# 13  2  3     {0}     1
# 14  2  4     {0}     1
# 15  2  5     {0}     1
# 16  2  6     {0}     1
# 17  2  7  {0, 3}     2
# 18  3  4     {0}     1
# 19  3  5     {0}     1
# 20  3  6     {0}     1
# 21  3  7     {0}     1
# 22  4  5     {0}     1
# 23  4  6     {0}     1
# 24  4  7     {0}     1
# 25  5  6     {0}     1
# 26  5  7     {0}     1
# 27  6  7     {0}     1

# %% [markdown]
# Venn diagram

# %%
venn_file = WORK / "venn.jpg"
if len(choices_df) in [2, 3]:
    if venn_file.is_file():
        display(IFrame(venn_file, 700, 350))

# %% [markdown]
# Sankey diagram (duplicates vs. unqiue instructions)

# %%
sankey_file =  WORK / "sankey.md"
with open(sankey_file, "r") as f:
    content = f.read()
display(Markdown(content))
# Out:
# ```mermaid
# ---
# config:
#   sankey:
#     showValues: true
# ---
# sankey-beta
#
# %% source,target,value
# Set0,Merged,1
# Set1,Merged,1
# Set2,Merged,2
# Set3,Merged,1
# Set4,Merged,1
# Set5,Merged,1
# Set6,Merged,1
# Set7,Merged,2
# Merged,Duplicates,8
# Merged,Unique,2
# Unique,Topk,2
#
# ```

# %% [markdown]
# ### Analyse combined index

# %%
combined_index_yaml = WORK / "combined_index.yml"
names_csv = WORK / "names.csv"
names_df = pd.read_csv(names_csv)
num_candidates = len(names_df)
names_df
# Out:
#      instr instr_lower
# 0  CUSTOM0     custom0
# 1  CUSTOM1     custom1

# %%
import yaml
with open(combined_index_yaml, "r") as f:
    combined_index_data = yaml.safe_load(f)

# %%
temp = combined_index_data["global"]["properties"]
filtered = list(filter(lambda x: x["candidate_count"] > 0, temp))
func_bbs_with_candidates = [(x["func"], x["bb"]) for x in filtered]
func_bbs_with_candidates_weights = [choices_df.where((choices_df["func_name"] == x[0]) & (choices_df["bb_name"] == x[1])).dropna()["rel_weight"].sum() for x in func_bbs_with_candidates]
func_bbs_with_candidates_weights_sum = sum(func_bbs_with_candidates_weights)
len(filtered), func_bbs_with_candidates_weights_sum
# Out:
# (8, 0.5975784937410219)

# %% [markdown]
# Analyze Encoding Footprint

# %%
import sys
sys.path.append("../scripts/")
from analyze_encoding import collect_weights, get_enc_weights_df, plot_enc_pie_multi, get_enc_score_df

# %%
enc_size = 32

total_weight, weight_per_instr, footprint_per_instr, rest_weight, bits_per_instr = collect_weights(combined_index_data, enc_size=enc_size)
enc_weights_df = get_enc_weights_df(total_weight, weight_per_instr, bits_per_instr, footprint_per_instr)
# enc_weights_df
enc_score_df = get_enc_score_df(enc_weights_df)
enc_score_df
# Out:
#      instr  bits  footprint    weight  enc_score
# 0  CUSTOM0  20.0        0.8  0.007812   0.992188
# 1  CUSTOM1  20.0        0.8  0.007812   0.992188

# %%
total_weight
# Out:
# 0.015625

# %% [markdown]
# Pie chart for enc weights (total and per custom instruction)

# %%
_ = plot_enc_pie_multi(weight_per_instr, rest_weight=rest_weight)

# %% [markdown]
# Number of candidates

# %%
num_candidates
# Out:
# 2

# %% [markdown]
# ## Analyze Graphs

# %%
dot_files = [Path(candidate_data["artifacts"]["io_sub"].replace(".pkl", ".dot")) for candidate_data in combined_index_data["candidates"]]
dot_files
# Out:
# [PosixPath('/work/git/isaac-demo/out/rnnoise_INT8/20250130T102419/work/tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91__%bb.6_0/io_sub82.dot'),
#  PosixPath('/work/git/isaac-demo/out/rnnoise_INT8/20250130T102419/work/tvmgen_default_fused_cast_subtract_fixed_point_multiply_add_nn_contrib_dense_pack_add_fixed_poi_44b8dd219ab79d91__%bb.10_0/io_sub82.dot')]

# %%
import graphviz

for i, dot_file in enumerate(dot_files):
    display(HTML(f"<h3>ID: {i}, File: {dot_file.name}</h3>"))
    with open(dot_file) as f:
        dot_graph = f.read()
    display(graphviz.Source(dot_graph))
# Out:
# <h3>ID: 0, File: io_sub82.dot</h3>
# <h3>ID: 1, File: io_sub82.dot</h3>

# %% [markdown]
# ## Generation of Instruction Set

# %% [markdown]
# Investigate generated Flat (unfused) CoreDSL per instruction

# %%
gen_dir = WORK / "gen"
for file in gen_dir.glob("*.flat"):
    display(HTML(f"<h3>File: {file.name}</h3>"))
    with open(file, "r") as f:
        code = f.read()
    display(Markdown(f"```c\n{code}\n```"""))
# Out:
# <h3>File: name0.flat</h3>
# ```c
# // DateTime: 20250130T105802, Sub: 0, Name: name0, Inputs: 3, Outputs: 1
# unsigned<32> rs3_val=X[rs3];
# unsigned<32> rs2_val=X[rs2];
# unsigned<32> rs1_val=X[rs1];
# unsigned<32> outp0=(unsigned<32>)(ADD((unsigned<32>)(MUL(rs1_val,rs2_val)),rs3_val));
# X[rd]=outp0;
# ```
# <h3>File: name1.flat</h3>
# ```c
# // DateTime: 20250130T105807, Sub: 1, Name: name1, Inputs: 3, Outputs: 1
# unsigned<32> rs1_val=X[rs1];
# unsigned<32> rs2_val=X[rs2];
# unsigned<32> rs3_val=X[rs3];
# unsigned<32> outp0=(unsigned<32>)(ADD((unsigned<32>)(MUL(rs3_val,rs2_val)),rs1_val));
# X[rd]=outp0;
# ```

# %% [markdown]
# CoreDSL Set with automatic encoding

# %%
set_file = WORK / "XIsaac.core_desc"

with open(set_file, "r") as f:
    code = f.read()

display(Markdown(f"```c\n{code}\n```"""))
# Out:
# ```c
# import "/work/git/isaac-demo/etiss_arch_riscv/rv_base/RVI.core_desc"
#
# InstructionSet XIsaac extends RV32I {
#     instructions {
#         CUSTOM0 {
#             encoding: 2'b00 :: rs3[4:0] :: rs2[4:0] :: rs1[4:0] :: 3'b000 :: rd[4:0] :: 7'b1111011;
#             assembly: {"custom0", "{name(rd)}, {name(rs1)}, {name(rs2)}, {name(rs3)}"};
#             behavior: {
#                 unsigned<32> rs3_val = X[rs3];
#                 unsigned<32> rs2_val = X[rs2];
#                 unsigned<32> rs1_val = X[rs1];
#                 unsigned<32> outp0 = (unsigned<32>)((((signed<32>)((unsigned<32>)((((signed<32>)(rs1_val) * (signed<32>)(rs2_val))))) + (signed<32>)(rs3_val))));
#                 X[rd] = outp0;
#             }
#         }
#         CUSTOM1 {
#             encoding: 2'b01 :: rs3[4:0] :: rs2[4:0] :: rs1[4:0] :: 3'b000 :: rd[4:0] :: 7'b1111011;
#             assembly: {"custom1", "{name(rd)}, {name(rs1)}, {name(rs2)}, {name(rs3)}"};
#             behavior: {
#                 unsigned<32> rs1_val = X[rs1];
#                 unsigned<32> rs2_val = X[rs2];
#                 unsigned<32> rs3_val = X[rs3];
#                 unsigned<32> outp0 = (unsigned<32>)((((signed<32>)((unsigned<32>)((((signed<32>)(rs3_val) * (signed<32>)(rs2_val))))) + (signed<32>)(rs1_val))));
#                 X[rd] = outp0;
#             }
#         }
#     }
# }
#
#
# ```

# %% [markdown]
# ## LLVM Retargeting

# %% [markdown]
# ## Seal5 Reports

# %%
reports_dir = WORK / "docker" / "seal5_reports"

# %% [markdown]
# ### Properties

# %%
properties_csv = reports_dir / "properties.csv"
pd.read_csv(properties_csv)
# Out:
#     model     set  xlen  is_rv32  is_rv64    instr  enc_size  is_compressed  \
# 0  XIsaac  XIsaac    32     True    False  CUSTOM0        32          False
# 1  XIsaac  XIsaac    32     True    False  CUSTOM1        32          False
#
#        enc_format    opcode  ...  is_simo  has_imm_leaf  has_side_effects  \
# 0  r-type (binop)  custom-3  ...    False         False             False
# 1  r-type (binop)  custom-3  ...    False         False             False
#
#    may_load  may_store  is_terminator  is_branch skip_pattern_gen  \
# 0     False      False          False      False            False
# 1     False      False          False      False            False
#
#    uses_custom_reg  defs_custom_reg
# 0            False            False
# 1            False            False
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Stage Times

# %%
stage_times_csv = reports_dir / "stage_times.csv"
pd.read_csv(stage_times_csv)[["stage", "time_s"]].dropna()
# Out:
#         stage      time_s
# 0       setup   35.539762
# 1       patch   17.859965
# 2       build  853.712861
# 3   transform    1.348287
# 4    generate    1.466015
# 5       patch   11.518617
# 6       build   63.740554
# 7       build    7.555806
# 8       build    7.492800
# 9    generate    1.240102
# 10      patch    2.859757
# 11      build   60.202009
# 12       test    0.000036
# 13      build   11.758841
# 14     deploy   30.740612
# 15     export    0.072562

# %% [markdown]
# ### Passes

# %%
seal5_status_csv = reports_dir / "status.csv"
seal5_status_compact_csv = reports_dir / "status_compact.csv"
seal5_status_df = pd.read_csv(seal5_status_csv)
seal5_status_compact_df = pd.read_csv(seal5_status_compact_csv)
seal5_status_compact_df
# Out:
#     model     set  xlen    instr  n_success  n_skipped  n_failed  n_total  \
# 0  XIsaac  XIsaac    32  CUSTOM0         14          0         0       14
# 1  XIsaac  XIsaac    32  CUSTOM1         14          0         0       14
#
#   status
# 0   good
# 1   good

# %% [markdown]
# ### Test Results/Coverage

# %%
# test_coverage_compact_csv = reports_dir / "test_coverage_compact.csv"
# pd.read_csv(test_coverage_compact_csv)

# %%
# test_results_compact_csv = reports_dir / "test_results_compact.csv"
# pd.read_csv(test_results_compact_csv)

# %% [markdown]
# ### Changed Files/Lines

# %%
seal5_diff_csv = reports_dir / "diff.csv"
seal5_diff_df = pd.read_csv(seal5_diff_csv)
seal5_diff_df
# Out:
#      phase  n_files_changed  n_insertions  n_deletions
# 0  PHASE_0               32          4604            5
# 1  PHASE_1                3            15            0
# 2  PHASE_2                4            96            0
# 3  PHASE_3                0             0            0
# 4  PHASE_4                3            22            0
# 5  PHASE_5                0             0            0
# 6        *               38          4737            5

# %%
seal5_diff_csv
# Out:
# PosixPath('../out/rnnoise_INT8/20250130T102419/work/docker/seal5_reports/diff.csv')

# %% [markdown]
# ### Seal5 Score

# %%
seal5_score_data = []
seal5_pattern_gen_status_df = seal5_status_df[seal5_status_df["pass"] == "generate_passes.pattern_gen.behav_to_pat"][["instr", "status"]]
seal5_passes_status_df = seal5_status_compact_df[["instr", "status"]]
# print("seal5_passes_status_df", seal5_passes_status_df)
for instr_name in seal5_status_df["instr"].unique():
    # print("instr_name", instr_name)
    passes_status = seal5_passes_status_df[seal5_passes_status_df["instr"] == instr_name]
    assert len(passes_status) == 1
    passes_status = passes_status["status"].iloc[0]
    passes_score = 1.0 if passes_status == "good" else (0.5 if passes_status == "ok" else 0.0)
    
    pattern_gen_status = seal5_pattern_gen_status_df[seal5_pattern_gen_status_df["instr"] == instr_name]
    assert len(pattern_gen_status) == 1
    pattern_gen_status = pattern_gen_status["status"].iloc[0]
    # print("pattern_gen_status", pattern_gen_status)
    pattern_gen_score = 1.0 if pattern_gen_status == "success" else -1.0
    # print("pattern_gen_score", pattern_gen_score)
    
    new = {"instr": instr_name, "pattern_gen_score": pattern_gen_score, "passes_score": passes_score}
    seal5_score_data.append(new)
    
def calc_seal5_score(x):
    return x.min()

seal5_score_df = pd.DataFrame(seal5_score_data)
seal5_score_df["seal5_score"] =  seal5_score_df[["pattern_gen_score", "passes_score"]].apply(calc_seal5_score, axis=1)
seal5_score_df
# TODO: write to file
# Out:
#      instr  pattern_gen_score  passes_score  seal5_score
# 0  CUSTOM0                1.0           1.0          1.0
# 1  CUSTOM1                1.0           1.0          1.0

# %% [markdown]
# ## ISS Evaluation

# %%
RUN_COMPARE = Path(str(RUN) + "_compare")
REPORT_COMPARE = RUN_COMPARE / "report.csv"

COLS = ["Model", "Arch", "Run Instructions", "Run Instructions (rel.)"]
bench_compare_df = pd.read_csv(REPORT_COMPARE)[COLS]
bench_compare_df
# Out:
#           Model             Arch  Run Instructions  Run Instructions (rel.)
# 0  rnnoise_INT8         rv32imfd            570276                 1.000000
# 1  rnnoise_INT8  rv32imfd_xisaac            445022                 0.780362

# %%
#TEMP
RUN_COMPARE = Path(str(RUN) + "_compare")
REPORT_COMPARE = RUN_COMPARE / "report.csv"

COLS = ["Model", "Arch", "Run Instructions", "Run Instructions (rel.)"]
bench_compare_df = pd.read_csv(REPORT_COMPARE)[COLS]
bench_compare_df
# Out:
#           Model             Arch  Run Instructions  Run Instructions (rel.)
# 0  rnnoise_INT8         rv32imfd            570276                 1.000000
# 1  rnnoise_INT8  rv32imfd_xisaac            445022                 0.780362

# %%
RUN_COMPARE_MEM = Path(str(RUN) + "_compare_mem")
REPORT_COMPARE_MEM = RUN_COMPARE_MEM / "report.csv"

COLS = ["Model", "Arch", "Total ROM", "Total RAM", "ROM code", "ROM code (rel.)"]
bench_compare_mem_df = pd.read_csv(REPORT_COMPARE_MEM)[COLS]
bench_compare_mem_df
# Out:
#           Model             Arch  Total ROM  Total RAM  ROM code  \
# 0  rnnoise_INT8         rv32imfd     283504       3636    104892
# 1  rnnoise_INT8  rv32imfd_xisaac     282576       3636    103964
#
#    ROM code (rel.)
# 0         1.000000
# 1         0.991153

# %%
# temp
RUN_COMPARE_MEM = Path(str(RUN) + "_compare_mem")
REPORT_COMPARE_MEM = RUN_COMPARE_MEM / "report.csv"

COLS = ["Model", "Arch", "Total ROM", "Total RAM", "ROM code", "ROM code (rel.)"]
bench_compare_mem_df = pd.read_csv(REPORT_COMPARE_MEM)[COLS]
bench_compare_mem_df
# Out:
#           Model             Arch  Total ROM  Total RAM  ROM code  \
# 0  rnnoise_INT8         rv32imfd     283504       3636    104892
# 1  rnnoise_INT8  rv32imfd_xisaac     282576       3636    103964
#
#    ROM code (rel.)
# 0         1.000000
# 1         0.991153

# %% [markdown]
# ### MLonMCU Score (Set)

# %%
assert len(bench_compare_df) == 2
run_instrs_rel = bench_compare_df["Run Instructions (rel.)"].iloc[-1]
assert len(bench_compare_mem_df) == 2
rom_code_rel = bench_compare_mem_df["ROM code (rel.)"].iloc[-1]

run_instrs_score = 1.0/run_instrs_rel-1
rom_code_score = 1.0/rom_code_rel-1

# TODO: cycles!

RUN_INSTR_WEIGHT_POS = 2
ROM_CODE_WEIGHT_POS = 1
RUN_INSTR_WEIGTH_NEG = 10
ROM_CODE_WEIGHT_NEG = 2

mlonmcu_set_score_data = [{"set": "XIsaac", "run_instrs_score": run_instrs_score, "rom_code_score": rom_code_score}]

def calc_mlonmcu_score(x):
    # return gmean([x["run_instrs_score"], x["rom_code_score"]], weights=[RUN_INSTR_WEIGHT, ROM_CODE_WEIGHT])
    a = x["run_instrs_score"]
    a = a * RUN_INSTR_WEIGHT_POS if a > 0 else a * RUN_INSTR_WEIGTH_NEG
    print(a)
    b = x["rom_code_score"]
    b = b * ROM_CODE_WEIGHT_POS if b > 0 else b * ROM_CODE_WEIGHT_NEG
    print(b)
    temp = a + b
    return max(-1.0, min(1.0, temp))

mlonmcu_set_score_df = pd.DataFrame(mlonmcu_set_score_data)
mlonmcu_set_score_df["mlonmcu_score"] =  mlonmcu_set_score_df[["run_instrs_score", "rom_code_score"]].apply(calc_mlonmcu_score, axis=1)
mlonmcu_set_score_df
# TODO: write to file
# Out:
# 0.562911496510285
# 0.008926166750028885
#       set  run_instrs_score  rom_code_score  mlonmcu_score
# 0  XIsaac          0.281456        0.008926       0.571838

# %% [markdown]
# ## Dynamic Analysis

# %%
SESS_NEW = DATE_DIR / "sess_new"
PLOTS_DIR_NEW = SESS_NEW / "plots"

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_llvm_bb.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess_new/plots/runtime_per_llvm_bb.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_func.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess_new/plots/runtime_per_func.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_opcode.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess_new/plots/runtime_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_instr.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250130T102419/sess_new/plots/runtime_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
opcodes_hist_file = SESS_NEW / "table" / "opcodes_hist.pkl"
opcodes_hist_df = pd.read_pickle(opcodes_hist_file)
print("All opcodes:")
display(opcodes_hist_df)
print("Custom only:")
display(opcodes_hist_df[opcodes_hist_df["opcode"].apply(lambda x: "custom" in x)])
# Out:
# All opcodes:
#                    opcode   count  rel_count
# 0                    LOAD  151850   0.330188
# 1          custom-3/rv128  126648   0.275388
# 2                  OP-IMM   59767   0.129960
# 3                  BRANCH   30186   0.065638
# 4                   OP-FP   19591   0.042599
# 5                      OP   16645   0.036194
# 6                   STORE   10512   0.022858
# 7                     LUI    9862   0.021444
# 8                 LOAD-FP    7537   0.016389
# 9     OP-IMM (Compressed)    4542   0.009876
# 10      JALR (Compressed)    4388   0.009541
# 11     STORE (Compressed)    2793   0.006073
# 12                   MADD    2667   0.005799
# 13       JAL (Compressed)    2035   0.004425
# 14      LOAD (Compressed)    2014   0.004379
# 15    BRANCH (Compressed)    1984   0.004314
# 16                    JAL    1281   0.002785
# 17  MISC-ALU (Compressed)    1223   0.002659
# 18   LOAD-FP (Compressed)    1127   0.002451
# 19               STORE-FP    1103   0.002398
# 20                  MNSUB    1089   0.002368
# 21  STORE-FP (Compressed)     743   0.001616
# 22                   MSUB     144   0.000313
# 23                   JALR      91   0.000198
# 24                 SYSTEM      55   0.000120
# 25                  AUIPC      12   0.000026
# Custom only:
#            opcode   count  rel_count
# 1  custom-3/rv128  126648   0.275388

# %%
instrs_hist_file = SESS_NEW / "table" / "instrs_hist.pkl"
instrs_hist_df = pd.read_pickle(instrs_hist_file)
print("All instructions:")
display(instrs_hist_df)
print("Custom only:")
custom_instrs_hist_df = instrs_hist_df[instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(custom_instrs_hist_df)
# Out:
# All instructions:
#       instr   count  rel_count
# 0        lh  140168   0.304787
# 1   custom0  126648   0.275388
# 2      addi   50378   0.109544
# 3       bne   18053   0.039255
# 4       lui    9862   0.021444
# ..      ...     ...        ...
# 91      ori      11   0.000024
# 92    csrai       6   0.000013
# 93      sll       2   0.000004
# 94    csrrw       1   0.000002
# 95      xor       1   0.000002
#
# [96 rows x 3 columns]
# Custom only:
#      instr   count  rel_count
# 1  custom0  126648   0.275388

# %%
# temp
instrs_hist_file = SESS_NEW / "table" / "instrs_hist.pkl"
instrs_hist_df = pd.read_pickle(instrs_hist_file)
print("All instructions:")
display(instrs_hist_df)
print("Custom only:")
custom_instrs_hist_df = instrs_hist_df[instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(custom_instrs_hist_df)
# Out:
# All instructions:
#       instr   count  rel_count
# 0        lh  140168   0.304787
# 1   custom0  126648   0.275388
# 2      addi   50378   0.109544
# 3       bne   18053   0.039255
# 4       lui    9862   0.021444
# ..      ...     ...        ...
# 91      ori      11   0.000024
# 92    csrai       6   0.000013
# 93      sll       2   0.000004
# 94    csrrw       1   0.000002
# 95      xor       1   0.000002
#
# [96 rows x 3 columns]
# Custom only:
#      instr   count  rel_count
# 1  custom0  126648   0.275388

# %%
dyn_counts_score_data = []

merged_custom_instrs_hist_df = pd.merge(names_df, custom_instrs_hist_df, how="outer", left_on="instr_lower", right_on="instr", suffixes=('', '_y'))

COUNT_WEIGHT = 1
CUSTOM_COUNT_WEIGHT = 1

instr_count_sum = instrs_hist_df["count"].sum()
instr_count_max = instrs_hist_df["count"].max()
print("instr_count", instr_count_sum, instr_count_max)
custom_count_sum = merged_custom_instrs_hist_df["count"].sum()
custom_count_max = merged_custom_instrs_hist_df["count"].max()
print("custom_count", custom_count_sum, custom_count_max)

for _, row_df in merged_custom_instrs_hist_df.iterrows():
    instr = row_df["instr"]
    count = row_df["count"]
    # rel_count = row_df["rel_count"]
    used = count > 0
    used_score = 1.0 if used else -1.0
    count_score = count/instr_count_max if used else -1.0
    custom_count_score = count/custom_count_max if used else -1.0
    new = {"instr": instr, "used_score": used_score, "count_score": count_score, "custom_count_score": custom_count_score}
    dyn_counts_score_data.append(new)

dyn_counts_score_df = pd.DataFrame(dyn_counts_score_data)
dyn_counts_score_df
# TODO: write to file
# Out:
# instr_count 459889 140168
# custom_count 126648.0 126648.0
#      instr  used_score  count_score  custom_count_score
# 0  CUSTOM0         1.0     0.903544                 1.0
# 1  CUSTOM1        -1.0    -1.000000                -1.0

# %% [markdown]
# ## Static Analysis

# %% [markdown]
# ### Instructions

# %%
disass_instrs_hist_file = SESS_NEW / "table" / "disass_instrs_hist.pkl"
disass_instrs_hist_df = pd.read_pickle(disass_instrs_hist_file)
print("All instructions:")
display(disass_instrs_hist_df)
print("Custom only:")
diass_custom_instrs_hist_df = disass_instrs_hist_df[disass_instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(diass_custom_instrs_hist_df)
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_instr.jpg", 700, 350))
# Out:
# All instructions:
#        instr  count  rel_count
# 0         sw   7082   0.177641
# 1         lw   5548   0.139163
# 2       addi   5027   0.126094
# 3         li   2156   0.054080
# 4        add   1355   0.033988
# ..       ...    ...        ...
# 106     divu      1   0.000025
# 107   fneg.d      1   0.000025
# 108    fle.d      1   0.000025
# 109  rdcycle      1   0.000025
# 110     mret      1   0.000025
#
# [111 rows x 3 columns]
# Custom only:
#       instr  count  rel_count
# 20  custom0    430   0.010786
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250129T100017/sess_new/plots/disass_counts_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# temp
disass_instrs_hist_file = SESS_NEW / "table" / "disass_instrs_hist.pkl"
disass_instrs_hist_df = pd.read_pickle(disass_instrs_hist_file)
print("All instructions:")
display(disass_instrs_hist_df)
print("Custom only:")
diass_custom_instrs_hist_df = disass_instrs_hist_df[disass_instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(diass_custom_instrs_hist_df)
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_instr.jpg", 700, 350))
# Out:
# All instructions:
#        instr  count  rel_count
# 0         sw   7082   0.177641
# 1         lw   5548   0.139163
# 2       addi   5027   0.126094
# 3         li   2156   0.054080
# 4        add   1355   0.033988
# ..       ...    ...        ...
# 106     divu      1   0.000025
# 107   fneg.d      1   0.000025
# 108    fle.d      1   0.000025
# 109  rdcycle      1   0.000025
# 110     mret      1   0.000025
#
# [111 rows x 3 columns]
# Custom only:
#       instr  count  rel_count
# 20  custom0    430   0.010786
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250129T100017/sess_new/plots/disass_counts_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
static_counts_score_data = []

merged_diass_custom_instrs_hist_df = pd.merge(names_df, diass_custom_instrs_hist_df, how="outer", left_on="instr_lower", right_on="instr", suffixes=('', '_y'))

COUNT_WEIGHT = 1
CUSTOM_COUNT_WEIGHT = 1

instr_count_sum = disass_instrs_hist_df["count"].sum()
instr_count_max = disass_instrs_hist_df["count"].max()
# print("instr_count", instr_count_sum, instr_count_max)
custom_count_sum = merged_diass_custom_instrs_hist_df["count"].sum()
custom_count_max = merged_diass_custom_instrs_hist_df["count"].max()
# print("custom_count", custom_count_sum, custom_count_max)

for _, row_df in merged_diass_custom_instrs_hist_df.iterrows():
    instr = row_df["instr"]
    count = row_df["count"]
    # rel_count = row_df["rel_count"]
    used = count > 0
    used_score = 1.0 if used else -1.0
    count_score = count/instr_count_max if used else -1.0
    custom_count_score = count/custom_count_max if used else -1.0
    new = {"instr": instr, "used_score": used_score, "count_score": count_score, "custom_count_score": custom_count_score}
    static_counts_score_data.append(new)

static_counts_score_df = pd.DataFrame(static_counts_score_data)
static_counts_score_df
# TODO: write to file
# Out:
#      instr  used_score  count_score  custom_count_score
# 0  CUSTOM0         1.0     0.060717                 1.0

# %% [markdown]
# ### Opcodes

# %%
disass_opcodes_hist_file = SESS_NEW / "table" / "disass_opcodes_hist.pkl"
disass_opcodes_hist_df = pd.read_pickle(disass_opcodes_hist_file)
print("All instructions:")
display(disass_opcodes_hist_df)
print("Custom only:")
display(disass_opcodes_hist_df[disass_opcodes_hist_df["opcode"].apply(lambda x: "custom" in x)])
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_opcode.jpg", 700, 350))
# Out:
# All instructions:
#                    opcode  count  rel_count
# 0                  OP-IMM   7156   0.179497
# 1                   STORE   7093   0.177917
# 2                    LOAD   6110   0.153260
# 3                      OP   3132   0.078561
# 4     OP-IMM (Compressed)   2247   0.056362
# 5                  BRANCH   2206   0.055334
# 6       JALR (Compressed)   1718   0.043093
# 7      STORE (Compressed)   1718   0.043093
# 8       LOAD (Compressed)   1653   0.041463
# 9                   OP-FP   1509   0.037851
# 10                    JAL   1151   0.028871
# 11                LOAD-FP    719   0.018035
# 12               STORE-FP    706   0.017709
# 13       JAL (Compressed)    691   0.017333
# 14                    LUI    550   0.013796
# 15  MISC-ALU (Compressed)    447   0.011212
# 16    BRANCH (Compressed)    436   0.010936
# 17         custom-3/rv128    430   0.010786
# 18                   JALR     64   0.001605
# 19                 SYSTEM     43   0.001079
# 20   LOAD-FP (Compressed)     27   0.000677
# 21                   MADD     26   0.000652
# 22                  MNSUB     14   0.000351
# 23  STORE-FP (Compressed)     11   0.000276
# 24                  AUIPC      8   0.000201
# 25                   MSUB      2   0.000050
# Custom only:
#             opcode  count  rel_count
# 17  custom-3/rv128    430   0.010786
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/rnnoise_INT8/20250129T100017/sess_new/plots/disass_counts_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# TODO: write utilization to file

# %%
PLOTS_DIR_NEW / "disass_counts_per_opcode.jpg"
# Out:
# PosixPath('../out/rnnoise_INT8/20250129T100017/sess_new/plots/disass_counts_per_opcode.jpg')

# %% [markdown]
# ## HLS Metrics

# %%
hls_metrics_csv = WORK / "docker" / "hls" / "hls_metrics.csv"
display(pd.read_csv(hls_metrics_csv))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[85], line 2
#       1 hls_metrics_csv = WORK / "docker" / "hls" / "hls_metrics.csv"
# ----> 2 display(pd.read_csv(hls_metrics_csv))
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../out/rnnoise_INT8/20250129T100017/work/docker/hls/hls_metrics.csv'

# %% [markdown]
# ## HW Synthesis Metrics

# %%
syn_best_csv = WORK / "docker" / "hls" / "syn_dir" / "best.csv"
display(pd.read_csv(syn_best_csv))

# %%
syn_metrics_csv = WORK / "docker" / "hls" / "syn_metrics.csv"
display(pd.read_csv(syn_metrics_csv))
# TODO: store baseline (without ext)!

# %%
# TODO: performance estimator?

# %% [markdown]
# ## LOCs Overview

# %%
from locs_helper import get_combined_locs_df
get_combined_locs_df(seal5_diff_csv=seal5_diff_csv, etiss_patch_stat="../out/nettle-aes/20241202T160512/work/docker/etiss_patch.stat", hls_metrics_csv=hls_metrics_csv)
# Out:
#     step  n_files_changed  n_insertions  n_deletions
# 0  seal5               32         728.0            0
# 1  etiss                1         986.0            0
# 2    rtl                1         434.0            0
