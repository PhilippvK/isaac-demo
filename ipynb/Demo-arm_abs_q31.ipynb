# %% [markdown]
# Configure notebook...

# %%
# %load_ext autoreload
# %autoreload 2
# %pwd
# Out:
# '/work/git/isaac-demo/ipynb'

# %% [markdown]
# Imports

# %%
from pathlib import Path
import datetime
import pandas as pd
from IPython.display import IFrame, HTML, Markdown, Image, display

# %% [markdown]
# Define benchmark

# %%
OUT_DIR_BASE = "../out"
BENCH = "cmsis_dsp/arm_abs_q31"
DATE = "latest"

# %% [markdown]
# Lookup directories

# %%
BENCH_DIR = Path(OUT_DIR_BASE) / BENCH
print("BENCH_DIR", BENCH_DIR)
assert BENCH_DIR.is_dir()
if DATE == "latest":
    dates = [f for f in BENCH_DIR.iterdir() if f.is_dir()]
    assert len(dates) > 0
    if len(dates) == 1:
        DATE = dates[0].name
    else:
        sorted_dates = sorted(dates, key=lambda x: datetime.datetime.strptime(x.name, "%Y%m%dT%H%M%S"))
        DATE = sorted_dates[-1].name
DATE_DIR = BENCH_DIR / DATE
assert DATE_DIR.is_dir()

print(f"Picked date: {DATE}")
print(f"Directory: {DATE_DIR}")

RUN = DATE_DIR / "run"
SESS = DATE_DIR / "sess"
WORK = DATE_DIR / "work"

PLOTS_DIR = SESS / "plots"
# Out:
# BENCH_DIR ../out/cmsis_dsp/arm_abs_q31
# Picked date: 20250129T163749
# Directory: ../out/cmsis_dsp/arm_abs_q31/20250129T163749

# %% [markdown]
# Check baseline benchmark (ISS)

# %%
REPORT = RUN / "report.csv"

COLS = ["Model", "Run Instructions", "Total ROM", "Total RAM"]
pd.read_csv(REPORT)[COLS]
# Out:
#          Model  Run Instructions  Total ROM  Total RAM
# 0  arm_abs_q31              1335      43608       3304

# %% [markdown]
# ## Trace Analysis

# %% [markdown]
# ### Identification of Bottlenecks

# %% [markdown]
# Per basic-block

# %%
IFrame(PLOTS_DIR / "runtime_per_llvm_bb.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_llvm_bb.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per function

# %%
IFrame(PLOTS_DIR / "runtime_per_func.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_func.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per library

# %%
IFrame(PLOTS_DIR / "runtime_per_library.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_library.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per object

# %%
IFrame(PLOTS_DIR / "runtime_per_object.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_object.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Analyze instruction types

# %% [markdown]
# Per major opcode

# %%
IFrame(PLOTS_DIR / "runtime_per_opcode.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Per instruction name

# %%
IFrame(PLOTS_DIR / "runtime_per_instr.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/cmsis_dsp/arm_abs_q31/20250129T163749/sess/plots/runtime_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Choose BBs for ISE identification

# %%
CHOICES = SESS / "table" / "choices.pkl"

choices_df = pd.read_pickle(CHOICES)
choices_df
# Out:
#      func_name                                               file bb_name  \
# 0  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.21
# 1  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.13
# 2  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...   %bb.9
# 3  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.17
# 4  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.29
# 5  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.28
# 6  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.27
# 7  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...  %bb.30
# 8  arm_abs_q31  /nas/ei/home/ga87puy/src/CMSIS-DSP/Source/Basi...   %bb.2
#
#    rel_weight  num_instrs  freq
# 0    0.154083           5  40.0
# 1    0.092450           3  40.0
# 2    0.092450           3  40.0
# 3    0.092450           3  40.0
# 4    0.076271           3  33.0
# 5    0.076271           3  33.0
# 6    0.076271           3  33.0
# 7    0.061633           2  40.0
# 8    0.061633           2  40.0

# %%
num_choices = len(choices_df)
choices_sum_weights = choices_df["rel_weight"].sum()
max_num_instrs = choices_df["num_instrs"].max()
num_choices, choices_sum_weights, max_num_instrs
# Out:
# (9, 0.783513097072419, 5)

# %% [markdown]
# ## Identification of ISE candidates

# %% [markdown]
# ### Per Func+BB

# %% [markdown]
# Filtered candidates

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: chekc suffix?
    pie_csv = func_bb_dir / "pie.csv"
    pie_img = func_bb_dir / "pie.png"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(pie_csv))
    display(Image(pie_img))
# Out:
# <h2>Func: arm_abs_q31, BB: %bb.21</h2>
#                  Label  Count
# 0  Filtered (Operands)      1
# <h2>Func: arm_abs_q31, BB: %bb.13</h2>
#             Label  Count
# 0  Filtered (Mem)      2
# <h2>Func: arm_abs_q31, BB: %bb.9</h2>
#             Label  Count
# 0  Filtered (Mem)      2
# <h2>Func: arm_abs_q31, BB: %bb.17</h2>
#             Label  Count
# 0  Filtered (Mem)      2
# <h2>Func: arm_abs_q31, BB: %bb.29</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.28</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.27</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.30</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.2</h2>
#             Label  Count
# 0  Filtered (Mem)      2

# %% [markdown]
# Generated variations

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: check suffix?
    pie2_csv = func_bb_dir / "pie2.csv"
    pie2_img = func_bb_dir / "pie2.png"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(pie2_csv))
    display(Image(pie2_img))
# Out:
# <h2>Func: arm_abs_q31, BB: %bb.21</h2>
#      Label  Count
# 0  Unknown      1
# <h2>Func: arm_abs_q31, BB: %bb.13</h2>
#      Label  Count
# 0  Unknown      2
# <h2>Func: arm_abs_q31, BB: %bb.9</h2>
#      Label  Count
# 0  Unknown      2
# <h2>Func: arm_abs_q31, BB: %bb.17</h2>
#      Label  Count
# 0  Unknown      2
# <h2>Func: arm_abs_q31, BB: %bb.29</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.28</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.27</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.30</h2>
# Empty DataFrame
# Columns: [Label, Count]
# Index: []
# <h2>Func: arm_abs_q31, BB: %bb.2</h2>
#      Label  Count
# 0  Unknown      2

# %% [markdown]
# Profile

# %%
for _, row_data in choices_df.iterrows():
    func_name = row_data["func_name"]
    bb_name = row_data["bb_name"]
    func_bb_dir = WORK / f"{func_name}_{bb_name}_0"  # TODO: chekc suffix?
    times_csv = func_bb_dir / "times.csv"
    display(HTML(f"<h2>Func: {func_name}, BB: {bb_name}</h2>"))
    display(pd.read_csv(times_csv))
# Out:
# <h2>Func: arm_abs_q31, BB: %bb.21</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000089     0.000069
# 1                    Connect to DB  0.000162     0.000125
# 2               Query func from DB  0.004749     0.003643
# 3         Query candidates from DB  0.006981     0.005355
# 4          Conversion to NX (func)  0.028177     0.021614
# 5    Conversion to NX (candidates)  0.000676     0.000518
# 6              Subgraph Generation  0.003776     0.002896
# 7                       Relabeling  0.001792     0.001374
# 8                 Dumping GF graph  0.012720     0.009757
# 9                     I/O Analysis  0.001439     0.001104
# 10                SubHash Creation  0.000623     0.000478
# 11               Isomorphism Check  0.000361     0.000277
# 12                   Overlap Check  0.000324     0.000249
# 13             Predicate Detection  0.000949     0.000728
# 14                   Schedule Subs  0.000867     0.000665
# 15             Filtering subgraphs  0.001114     0.000855
# 16            Determining IO names  0.001547     0.001187
# 17               Analyze Constants  0.001213     0.000931
# 18   Creating Constants Histograms  0.001331     0.001021
# 19            Variation generation  0.000018     0.000014
# 20               FullHash Creation  0.003418     0.002622
# 21  Filtering subgraphs (Operands)  0.001379     0.001058
# 22  Filtering subgraphs (Encoding)  0.001755     0.001346
# 23   Filtering subgraphs (Weights)  0.001427     0.001095
# 24                 Tree Generation  0.000195     0.000149
# 25                       Finish DF  0.000702     0.000539
# 26                    Apply Styles  0.001338     0.001026
# 27                 Subgraph Export  0.001329     0.001020
# 28           Dumping I/O Subgraphs  0.001390     0.001066
# 29                        Dump DFs  0.003223     0.002472
# 30                    Generate Pie  0.332062     0.254714
# 31                        Dump Pie  0.870137     0.667452
# 32               Dump Sankey chart  0.009009     0.006911
# 33                     Write Index  0.007392     0.005670
# <h2>Func: arm_abs_q31, BB: %bb.13</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000090     0.000071
# 1                    Connect to DB  0.000142     0.000112
# 2               Query func from DB  0.004738     0.003717
# 3         Query candidates from DB  0.003741     0.002935
# 4          Conversion to NX (func)  0.025772     0.020216
# 5    Conversion to NX (candidates)  0.001150     0.000902
# 6              Subgraph Generation  0.003703     0.002905
# 7                       Relabeling  0.001823     0.001430
# 8                 Dumping GF graph  0.012436     0.009755
# 9                     I/O Analysis  0.002065     0.001620
# 10                SubHash Creation  0.000841     0.000660
# 11               Isomorphism Check  0.000527     0.000414
# 12                   Overlap Check  0.000496     0.000389
# 13             Predicate Detection  0.001317     0.001033
# 14                   Schedule Subs  0.001132     0.000888
# 15             Filtering subgraphs  0.001435     0.001126
# 16            Determining IO names  0.001801     0.001413
# 17               Analyze Constants  0.001343     0.001053
# 18   Creating Constants Histograms  0.001320     0.001036
# 19            Variation generation  0.000018     0.000014
# 20               FullHash Creation  0.003264     0.002561
# 21  Filtering subgraphs (Operands)  0.001467     0.001151
# 22  Filtering subgraphs (Encoding)  0.001402     0.001100
# 23   Filtering subgraphs (Weights)  0.001348     0.001057
# 24                 Tree Generation  0.000189     0.000149
# 25                       Finish DF  0.000700     0.000549
# 26                    Apply Styles  0.001373     0.001077
# 27                 Subgraph Export  0.001322     0.001037
# 28           Dumping I/O Subgraphs  0.001314     0.001031
# 29                        Dump DFs  0.003343     0.002623
# 30                    Generate Pie  0.334097     0.262075
# 31                        Dump Pie  0.844672     0.662585
# 32               Dump Sankey chart  0.008037     0.006305
# 33                     Write Index  0.006394     0.005015
# <h2>Func: arm_abs_q31, BB: %bb.9</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000093     0.000069
# 1                    Connect to DB  0.000158     0.000116
# 2               Query func from DB  0.009252     0.006808
# 3         Query candidates from DB  0.008267     0.006083
# 4          Conversion to NX (func)  0.061034     0.044910
# 5    Conversion to NX (candidates)  0.001658     0.001220
# 6              Subgraph Generation  0.003986     0.002933
# 7                       Relabeling  0.001858     0.001367
# 8                 Dumping GF graph  0.012798     0.009417
# 9                     I/O Analysis  0.002054     0.001511
# 10                SubHash Creation  0.000897     0.000660
# 11               Isomorphism Check  0.000554     0.000408
# 12                   Overlap Check  0.000506     0.000372
# 13             Predicate Detection  0.001328     0.000977
# 14                   Schedule Subs  0.001182     0.000870
# 15             Filtering subgraphs  0.001478     0.001088
# 16            Determining IO names  0.001796     0.001321
# 17               Analyze Constants  0.001436     0.001057
# 18   Creating Constants Histograms  0.001340     0.000986
# 19            Variation generation  0.000018     0.000013
# 20               FullHash Creation  0.003314     0.002439
# 21  Filtering subgraphs (Operands)  0.001482     0.001090
# 22  Filtering subgraphs (Encoding)  0.001497     0.001102
# 23   Filtering subgraphs (Weights)  0.001441     0.001060
# 24                 Tree Generation  0.000190     0.000140
# 25                       Finish DF  0.000707     0.000520
# 26                    Apply Styles  0.001374     0.001011
# 27                 Subgraph Export  0.001346     0.000990
# 28           Dumping I/O Subgraphs  0.001327     0.000977
# 29                        Dump DFs  0.003331     0.002451
# 30                    Generate Pie  0.330493     0.243182
# 31                        Dump Pie  0.879001     0.646781
# 32               Dump Sankey chart  0.010544     0.007759
# 33                     Write Index  0.011297     0.008313
# <h2>Func: arm_abs_q31, BB: %bb.17</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000086     0.000067
# 1                    Connect to DB  0.000163     0.000127
# 2               Query func from DB  0.005907     0.004594
# 3         Query candidates from DB  0.008239     0.006408
# 4          Conversion to NX (func)  0.064210     0.049937
# 5    Conversion to NX (candidates)  0.001658     0.001290
# 6              Subgraph Generation  0.004103     0.003191
# 7                       Relabeling  0.001858     0.001445
# 8                 Dumping GF graph  0.012728     0.009898
# 9                     I/O Analysis  0.002031     0.001580
# 10                SubHash Creation  0.000892     0.000694
# 11               Isomorphism Check  0.000559     0.000434
# 12                   Overlap Check  0.000520     0.000404
# 13             Predicate Detection  0.001342     0.001044
# 14                   Schedule Subs  0.001158     0.000900
# 15             Filtering subgraphs  0.001445     0.001124
# 16            Determining IO names  0.001783     0.001386
# 17               Analyze Constants  0.001414     0.001100
# 18   Creating Constants Histograms  0.001346     0.001047
# 19            Variation generation  0.000018     0.000014
# 20               FullHash Creation  0.003329     0.002589
# 21  Filtering subgraphs (Operands)  0.001486     0.001156
# 22  Filtering subgraphs (Encoding)  0.001459     0.001134
# 23   Filtering subgraphs (Weights)  0.001458     0.001134
# 24                 Tree Generation  0.000191     0.000148
# 25                       Finish DF  0.000723     0.000562
# 26                    Apply Styles  0.001369     0.001065
# 27                 Subgraph Export  0.001369     0.001065
# 28           Dumping I/O Subgraphs  0.001376     0.001070
# 29                        Dump DFs  0.003402     0.002646
# 30                    Generate Pie  0.336437     0.261652
# 31                        Dump Pie  0.813655     0.632791
# 32               Dump Sankey chart  0.004181     0.003252
# 33                     Write Index  0.003924     0.003051
# <h2>Func: arm_abs_q31, BB: %bb.29</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000089     0.000068
# 1                    Connect to DB  0.000171     0.000130
# 2               Query func from DB  0.005249     0.004016
# 3         Query candidates from DB  0.008797     0.006731
# 4          Conversion to NX (func)  0.066205     0.050656
# 5    Conversion to NX (candidates)  0.000127     0.000097
# 6              Subgraph Generation  0.003837     0.002936
# 7                       Relabeling  0.001695     0.001297
# 8                 Dumping GF graph  0.012765     0.009767
# 9                     I/O Analysis  0.000202     0.000154
# 10                SubHash Creation  0.000103     0.000079
# 11               Isomorphism Check  0.000206     0.000158
# 12                   Overlap Check  0.000018     0.000014
# 13             Predicate Detection  0.000285     0.000218
# 14                   Schedule Subs  0.000300     0.000230
# 15             Filtering subgraphs  0.000658     0.000503
# 16            Determining IO names  0.000970     0.000742
# 17               Analyze Constants  0.000840     0.000642
# 18   Creating Constants Histograms  0.000792     0.000606
# 19            Variation generation  0.000035     0.000026
# 20               FullHash Creation  0.003026     0.002315
# 21  Filtering subgraphs (Operands)  0.000931     0.000713
# 22  Filtering subgraphs (Encoding)  0.000913     0.000699
# 23   Filtering subgraphs (Weights)  0.000929     0.000711
# 24                 Tree Generation  0.000157     0.000120
# 25                       Finish DF  0.000533     0.000408
# 26                    Apply Styles  0.000805     0.000616
# 27                 Subgraph Export  0.000827     0.000633
# 28           Dumping I/O Subgraphs  0.000827     0.000633
# 29                        Dump DFs  0.002869     0.002195
# 30                    Generate Pie  0.335317     0.256563
# 31                        Dump Pie  0.840008     0.642721
# 32               Dump Sankey chart  0.009994     0.007647
# 33                     Write Index  0.006479     0.004957
# <h2>Func: arm_abs_q31, BB: %bb.28</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000085     0.000068
# 1                    Connect to DB  0.000163     0.000129
# 2               Query func from DB  0.005378     0.004264
# 3         Query candidates from DB  0.008100     0.006423
# 4          Conversion to NX (func)  0.053362     0.042314
# 5    Conversion to NX (candidates)  0.000142     0.000113
# 6              Subgraph Generation  0.004166     0.003303
# 7                       Relabeling  0.001697     0.001346
# 8                 Dumping GF graph  0.012785     0.010138
# 9                     I/O Analysis  0.000195     0.000155
# 10                SubHash Creation  0.000120     0.000095
# 11               Isomorphism Check  0.000216     0.000171
# 12                   Overlap Check  0.000018     0.000014
# 13             Predicate Detection  0.000306     0.000242
# 14                   Schedule Subs  0.000306     0.000243
# 15             Filtering subgraphs  0.000660     0.000524
# 16            Determining IO names  0.000972     0.000770
# 17               Analyze Constants  0.000858     0.000681
# 18   Creating Constants Histograms  0.000818     0.000649
# 19            Variation generation  0.000018     0.000015
# 20               FullHash Creation  0.002942     0.002333
# 21  Filtering subgraphs (Operands)  0.000929     0.000737
# 22  Filtering subgraphs (Encoding)  0.000912     0.000723
# 23   Filtering subgraphs (Weights)  0.000904     0.000717
# 24                 Tree Generation  0.000154     0.000122
# 25                       Finish DF  0.000522     0.000414
# 26                    Apply Styles  0.000797     0.000632
# 27                 Subgraph Export  0.000811     0.000643
# 28           Dumping I/O Subgraphs  0.000805     0.000639
# 29                        Dump DFs  0.002847     0.002257
# 30                    Generate Pie  0.333477     0.264434
# 31                        Dump Pie  0.813991     0.645462
# 32               Dump Sankey chart  0.006430     0.005099
# 33                     Write Index  0.005210     0.004131
# <h2>Func: arm_abs_q31, BB: %bb.27</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000090     0.000076
# 1                    Connect to DB  0.000188     0.000157
# 2               Query func from DB  0.004699     0.003938
# 3         Query candidates from DB  0.007189     0.006025
# 4          Conversion to NX (func)  0.026763     0.022429
# 5    Conversion to NX (candidates)  0.000124     0.000104
# 6              Subgraph Generation  0.003687     0.003090
# 7                       Relabeling  0.001663     0.001393
# 8                 Dumping GF graph  0.012660     0.010610
# 9                     I/O Analysis  0.000225     0.000189
# 10                SubHash Creation  0.000133     0.000111
# 11               Isomorphism Check  0.000223     0.000187
# 12                   Overlap Check  0.000022     0.000018
# 13             Predicate Detection  0.000312     0.000262
# 14                   Schedule Subs  0.000321     0.000269
# 15             Filtering subgraphs  0.000667     0.000559
# 16            Determining IO names  0.001008     0.000845
# 17               Analyze Constants  0.000852     0.000714
# 18   Creating Constants Histograms  0.000806     0.000676
# 19            Variation generation  0.000023     0.000019
# 20               FullHash Creation  0.002957     0.002479
# 21  Filtering subgraphs (Operands)  0.000916     0.000768
# 22  Filtering subgraphs (Encoding)  0.000904     0.000758
# 23   Filtering subgraphs (Weights)  0.000931     0.000780
# 24                 Tree Generation  0.000164     0.000137
# 25                       Finish DF  0.000523     0.000439
# 26                    Apply Styles  0.000804     0.000674
# 27                 Subgraph Export  0.000818     0.000686
# 28           Dumping I/O Subgraphs  0.000840     0.000704
# 29                        Dump DFs  0.002770     0.002322
# 30                    Generate Pie  0.330241     0.276764
# 31                        Dump Pie  0.771883     0.646891
# 32               Dump Sankey chart  0.010242     0.008584
# 33                     Write Index  0.007573     0.006346
# <h2>Func: arm_abs_q31, BB: %bb.30</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000096     0.000074
# 1                    Connect to DB  0.000171     0.000132
# 2               Query func from DB  0.009263     0.007148
# 3         Query candidates from DB  0.008041     0.006204
# 4          Conversion to NX (func)  0.058625     0.045237
# 5    Conversion to NX (candidates)  0.000159     0.000122
# 6              Subgraph Generation  0.003787     0.002922
# 7                       Relabeling  0.001750     0.001350
# 8                 Dumping GF graph  0.012762     0.009848
# 9                     I/O Analysis  0.000209     0.000162
# 10                SubHash Creation  0.000136     0.000105
# 11               Isomorphism Check  0.000219     0.000169
# 12                   Overlap Check  0.000024     0.000019
# 13             Predicate Detection  0.000315     0.000243
# 14                   Schedule Subs  0.000331     0.000255
# 15             Filtering subgraphs  0.000654     0.000504
# 16            Determining IO names  0.000963     0.000743
# 17               Analyze Constants  0.000853     0.000658
# 18   Creating Constants Histograms  0.000813     0.000628
# 19            Variation generation  0.000022     0.000017
# 20               FullHash Creation  0.002845     0.002196
# 21  Filtering subgraphs (Operands)  0.000946     0.000730
# 22  Filtering subgraphs (Encoding)  0.000923     0.000712
# 23   Filtering subgraphs (Weights)  0.000921     0.000710
# 24                 Tree Generation  0.000170     0.000131
# 25                       Finish DF  0.000536     0.000414
# 26                    Apply Styles  0.000812     0.000627
# 27                 Subgraph Export  0.000787     0.000607
# 28           Dumping I/O Subgraphs  0.000815     0.000629
# 29                        Dump DFs  0.002802     0.002162
# 30                    Generate Pie  0.333141     0.257066
# 31                        Dump Pie  0.841803     0.649571
# 32               Dump Sankey chart  0.005802     0.004477
# 33                     Write Index  0.004441     0.003427
# <h2>Func: arm_abs_q31, BB: %bb.2</h2>
#                               Name      Secs  Secs (rel.)
# 0              Settings Validation  0.000096     0.000074
# 1                    Connect to DB  0.000166     0.000127
# 2               Query func from DB  0.004978     0.003817
# 3         Query candidates from DB  0.008222     0.006304
# 4          Conversion to NX (func)  0.027233     0.020879
# 5    Conversion to NX (candidates)  0.001149     0.000881
# 6              Subgraph Generation  0.003806     0.002918
# 7                       Relabeling  0.001855     0.001422
# 8                 Dumping GF graph  0.012821     0.009829
# 9                     I/O Analysis  0.002089     0.001602
# 10                SubHash Creation  0.000874     0.000670
# 11               Isomorphism Check  0.000543     0.000417
# 12                   Overlap Check  0.000504     0.000386
# 13             Predicate Detection  0.001354     0.001038
# 14                   Schedule Subs  0.001154     0.000885
# 15             Filtering subgraphs  0.001432     0.001098
# 16            Determining IO names  0.001824     0.001398
# 17               Analyze Constants  0.001363     0.001045
# 18   Creating Constants Histograms  0.001347     0.001033
# 19            Variation generation  0.000018     0.000014
# 20               FullHash Creation  0.003321     0.002546
# 21  Filtering subgraphs (Operands)  0.001488     0.001141
# 22  Filtering subgraphs (Encoding)  0.001442     0.001105
# 23   Filtering subgraphs (Weights)  0.001443     0.001106
# 24                 Tree Generation  0.000182     0.000139
# 25                       Finish DF  0.000722     0.000554
# 26                    Apply Styles  0.001363     0.001045
# 27                 Subgraph Export  0.001390     0.001066
# 28           Dumping I/O Subgraphs  0.001373     0.001052
# 29                        Dump DFs  0.003377     0.002589
# 30                    Generate Pie  0.335814     0.257462
# 31                        Dump Pie  0.862823     0.661510
# 32               Dump Sankey chart  0.009274     0.007110
# 33                     Write Index  0.007483     0.005737

# %% [markdown]
# ### Combined results

# %% [markdown]
# Pairwise overlaps

# %%
overlaps_file = WORK / "overlaps.csv"
pd.read_csv(overlaps_file)
# Out:
#     x  y  nodes  size
# 0   0  1  set()     0
# 1   0  2  set()     0
# 2   0  3  set()     0
# 3   0  4  set()     0
# 4   0  5  set()     0
# 5   0  6  set()     0
# 6   0  7  set()     0
# 7   0  8  set()     0
# 8   1  2  set()     0
# 9   1  3  set()     0
# 10  1  4  set()     0
# 11  1  5  set()     0
# 12  1  6  set()     0
# 13  1  7  set()     0
# 14  1  8  set()     0
# 15  2  3  set()     0
# 16  2  4  set()     0
# 17  2  5  set()     0
# 18  2  6  set()     0
# 19  2  7  set()     0
# 20  2  8  set()     0
# 21  3  4  set()     0
# 22  3  5  set()     0
# 23  3  6  set()     0
# 24  3  7  set()     0
# 25  3  8  set()     0
# 26  4  5  set()     0
# 27  4  6  set()     0
# 28  4  7  set()     0
# 29  4  8  set()     0
# 30  5  6  set()     0
# 31  5  7  set()     0
# 32  5  8  set()     0
# 33  6  7  set()     0
# 34  6  8  set()     0
# 35  7  8  set()     0

# %% [markdown]
# Venn diagram

# %%
venn_file = WORK / "venn.jpg"
if len(choices_df) in [2, 3]:
    if venn_file.is_file():
        display(IFrame(venn_file, 700, 350))

# %% [markdown]
# Sankey diagram (duplicates vs. unqiue instructions)

# %%
sankey_file =  WORK / "sankey.md"
with open(sankey_file, "r") as f:
    content = f.read()
display(Markdown(content))
# Out:
# ```mermaid
# ---
# config:
#   sankey:
#     showValues: true
# ---
# sankey-beta
#
# %% source,target,value
# Set0,Merged,0
# Set1,Merged,0
# Set2,Merged,0
# Set3,Merged,0
# Set4,Merged,0
# Set5,Merged,0
# Set6,Merged,0
# Set7,Merged,0
# Set8,Merged,0
# Merged,Duplicates,0
# Merged,Unique,0
# Unique,Topk,0
#
# ```

# %% [markdown]
# ### Analyse combined index

# %%
combined_index_yaml = WORK / "combined_index.yml"
names_csv = WORK / "names.csv"
names_df = pd.read_csv(names_csv)
num_candidates = len(names_df)
names_df
# Out:
# Empty DataFrame
# Columns: [instr, instr_lower]
# Index: []

# %%
import yaml
with open(combined_index_yaml, "r") as f:
    combined_index_data = yaml.safe_load(f)

# %% [markdown]
# Analyze Encoding Footprint

# %%
import sys
sys.path.append("../scripts/")
from analyze_encoding import collect_weights, get_enc_weights_df, plot_enc_pie_multi, get_enc_score_df

# %%
enc_size = 32

total_weight, weight_per_instr, footprint_per_instr, rest_weight, bits_per_instr = collect_weights(combined_index_data, enc_size=enc_size)
enc_weights_df = get_enc_weights_df(total_weight, weight_per_instr, bits_per_instr, footprint_per_instr)
# enc_weights_df
enc_score_df = get_enc_score_df(enc_weights_df)
enc_score_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 6
#       4 enc_weights_df = get_enc_weights_df(total_weight, weight_per_instr, bits_per_instr, footprint_per_instr)
#       5 # enc_weights_df
# ----> 6 enc_score_df = get_enc_score_df(enc_weights_df)
#       7 enc_score_df
#
# File /work/git/isaac-demo/ipynb/../scripts/analyze_encoding.py:177, in get_enc_score_df(enc_weights_df)
#     175 def get_enc_score_df(enc_weights_df):
#     176     score_df = enc_weights_df.copy().dropna()
# --> 177     score_df["enc_score"] = score_df.loc[:, ["footprint", "weight"]].apply(
#     178         lambda x: -1 if x["footprint"] > 1.0 else (1.0 - x["weight"]), axis=1
#     179     )
#     180     return score_df
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1289, in _LocIndexer._getitem_tuple(self, tup)
#    1286 if self._multi_take_opportunity(tup):
#    1287     return self._multi_take(tup)
# -> 1289 return self._getitem_tuple_same_dim(tup)
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:955, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     952 if com.is_null_slice(key):
#     953     continue
# --> 955 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     956 # We should never have retval.ndim < self.ndim, as that should
#     957 #  be handled by the _getitem_lowerdim call above.
#     958 assert retval.ndim == self.ndim
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['footprint'] not in index"

# %%
total_weight

# %% [markdown]
# Pie chart for enc weights (total and per custom instruction)

# %%
_ = plot_enc_pie_multi(weight_per_instr, rest_weight=rest_weight)

# %% [markdown]
# Number of candidates

# %%
num_candidates
# Out:
# 1

# %% [markdown]
# ## Generation of Instruction Set

# %% [markdown]
# Investigate generated Flat (unfused) CoreDSL per instruction

# %%
gen_dir = WORK / "gen"
for file in gen_dir.glob("*.flat"):
    display(HTML(f"<h3>File: {file.name}</h2>"))
    with open(file, "r") as f:
        code = f.read()
    display(Markdown(f"```c\n{code}\n```"""))
# Out:
# <h3>File: name0.flat</h2>
# ```c
# // DateTime: 20250129T113918, Sub: 0, Name: name0, Inputs: 3, Outputs: 1
# unsigned<32> rs3_val=X[rs3];
# unsigned<32> rs2_val=X[rs2];
# unsigned<32> rs1_val=X[rs1];
# unsigned<32> outp0=(unsigned<32>)(ADD((unsigned<32>)(MUL(rs1_val,rs2_val)),rs3_val));
# X[rd]=outp0;
# ```

# %% [markdown]
# CoreDSL Set with automatic encoding

# %%
set_file = WORK / "XIsaac.core_desc"

with open(set_file, "r") as f:
    code = f.read()

display(Markdown(f"```c\n{code}\n```"""))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 3
#       1 set_file = WORK / "XIsaac.core_desc"
# ----> 3 with open(set_file, "r") as f:
#       4     code = f.read()
#       6 display(Markdown(f"```c\n{code}\n```"""))
#
# File /work/git/isaac-demo/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../out/rnnoise_INT8/20250129T100017/work/XIsaac.core_desc'

# %% [markdown]
# ## LLVM Retargeting

# %% [markdown]
# ## Seal5 Reports

# %%
reports_dir = WORK / "docker" / "seal5_reports"

# %% [markdown]
# ### Properties

# %%
properties_csv = reports_dir / "properties.csv"
pd.read_csv(properties_csv)
# Out:
#      model     set  xlen  is_rv32  is_rv64     instr  enc_size  is_compressed  \
# 0   XIsaac  XIsaac    32     True    False   CUSTOM0        32          False
# 1   XIsaac  XIsaac    32     True    False   CUSTOM1        32          False
# 2   XIsaac  XIsaac    32     True    False   CUSTOM2        32          False
# 3   XIsaac  XIsaac    32     True    False   CUSTOM3        32          False
# 4   XIsaac  XIsaac    32     True    False   CUSTOM4        32          False
# 5   XIsaac  XIsaac    32     True    False   CUSTOM5        32          False
# 6   XIsaac  XIsaac    32     True    False   CUSTOM6        32          False
# 7   XIsaac  XIsaac    32     True    False   CUSTOM7        32          False
# 8   XIsaac  XIsaac    32     True    False   CUSTOM8        32          False
# 9   XIsaac  XIsaac    32     True    False   CUSTOM9        32          False
# 10  XIsaac  XIsaac    32     True    False  CUSTOM10        32          False
# 11  XIsaac  XIsaac    32     True    False  CUSTOM11        32          False
# 12  XIsaac  XIsaac    32     True    False  CUSTOM12        32          False
#
#         enc_format    opcode  ...  is_siso  is_simo  has_imm_leaf  \
# 0   r-type (binop)  custom-3  ...    False    False         False
# 1   r-type (binop)  custom-3  ...    False    False         False
# 2   r-type (binop)  custom-3  ...    False    False         False
# 3    r-type (unop)  custom-3  ...     True    False         False
# 4    r-type (unop)  custom-3  ...     True    False         False
# 5    r-type (unop)  custom-3  ...     True    False         False
# 6    r-type (unop)  custom-3  ...     True    False         False
# 7   r-type (binop)  custom-3  ...    False    False         False
# 8   r-type (binop)  custom-3  ...    False    False         False
# 9   r-type (binop)  custom-3  ...    False    False         False
# 10  r-type (binop)  custom-3  ...    False    False         False
# 11  r-type (binop)  custom-3  ...    False    False         False
# 12  r-type (binop)  custom-3  ...    False    False         False
#
#     has_side_effects  may_load  may_store  is_terminator is_branch  \
# 0              False     False      False          False     False
# 1              False     False      False          False     False
# 2              False     False      False          False     False
# 3              False     False      False          False     False
# 4              False     False      False          False     False
# 5              False     False      False          False     False
# 6              False     False      False          False     False
# 7              False     False      False          False     False
# 8              False     False      False          False     False
# 9              False     False      False          False     False
# 10             False     False      False          False     False
# 11             False     False      False          False     False
# 12             False     False      False          False     False
#
#     uses_custom_reg  defs_custom_reg
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False
# 5             False            False
# 6             False            False
# 7             False            False
# 8             False            False
# 9             False            False
# 10            False            False
# 11            False            False
# 12            False            False
#
# [13 rows x 34 columns]

# %% [markdown]
# ### Stage Times

# %%
stage_times_csv = reports_dir / "stage_times.csv"
pd.read_csv(stage_times_csv)[["stage", "time_s"]].dropna()
# Out:
#         stage      time_s
# 0       setup   38.525705
# 1       patch   18.895561
# 2       build  873.806360
# 3   transform    1.505749
# 4    generate    1.470800
# 5       patch   11.247951
# 6       build   59.737247
# 7       build    7.439931
# 8       build    7.460552
# 9    generate    2.102515
# 10      patch    2.922808
# 11      build   58.973045
# 12       test    0.000038
# 13      build   12.247571
# 14     deploy   30.085947
# 15     export    0.091977

# %% [markdown]
# ### Passes

# %%
seal5_status_csv = reports_dir / "status.csv"
seal5_status_compact_csv = reports_dir / "status_compact.csv"
seal5_status_df = pd.read_csv(seal5_status_csv)
seal5_status_compact_df = pd.read_csv(seal5_status_compact_csv)
seal5_status_compact_df
# Out:
#      model     set  xlen     instr  n_success  n_skipped  n_failed  n_total  \
# 0   XIsaac  XIsaac    32   CUSTOM0         12          0         0       12
# 1   XIsaac  XIsaac    32   CUSTOM1         12          0         0       12
# 2   XIsaac  XIsaac    32   CUSTOM2         12          0         0       12
# 3   XIsaac  XIsaac    32   CUSTOM3         12          0         0       12
# 4   XIsaac  XIsaac    32   CUSTOM4         12          0         0       12
# 5   XIsaac  XIsaac    32   CUSTOM5         12          0         0       12
# 6   XIsaac  XIsaac    32   CUSTOM6         12          0         0       12
# 7   XIsaac  XIsaac    32   CUSTOM7         12          0         0       12
# 8   XIsaac  XIsaac    32   CUSTOM8         12          0         0       12
# 9   XIsaac  XIsaac    32   CUSTOM9         12          0         0       12
# 10  XIsaac  XIsaac    32  CUSTOM10         12          0         0       12
# 11  XIsaac  XIsaac    32  CUSTOM11         12          0         0       12
# 12  XIsaac  XIsaac    32  CUSTOM12         12          0         0       12
#
#    status
# 0    good
# 1    good
# 2    good
# 3    good
# 4    good
# 5    good
# 6    good
# 7    good
# 8    good
# 9    good
# 10   good
# 11   good
# 12   good

# %% [markdown]
# ### Test Results/Coverage

# %%
# test_coverage_compact_csv = reports_dir / "test_coverage_compact.csv"
# pd.read_csv(test_coverage_compact_csv)

# %%
# test_results_compact_csv = reports_dir / "test_results_compact.csv"
# pd.read_csv(test_results_compact_csv)

# %% [markdown]
# ### Changed Files/Lines

# %%
seal5_diff_csv = reports_dir / "diff.csv"
seal5_diff_df = pd.read_csv(seal5_diff_csv)
seal5_diff_df
# Out:
#      phase  n_files_changed  n_insertions  n_deletions
# 0  PHASE_0               29          4402            5
# 1  PHASE_1                3            15            0
# 2  PHASE_2               15           570            0
# 3  PHASE_3                0             0            0
# 4  PHASE_4               14           143            0
# 5  PHASE_5                0             0            0
# 6        *               57          5130            5

# %%
seal5_diff_csv
# Out:
# PosixPath('../out/nettle-aes/20241202T160512/work/docker/seal5_reports/diff.csv')

# %%
# Out:
# seal5_phases ['PHASE_1', 'PHASE_2', 'PHASE_3', 'PHASE_4', 'PHASE_5']
#     step  n_files_changed  n_insertions  n_deletions
# 0  seal5               32           728            0
# 1  etiss                1           986            0

# %% [markdown]
# ### Seal5 Score

# %%
seal5_score_data = []
seal5_pattern_gen_status_df = seal5_status_df[seal5_status_df["pass"] == "generate_passes.pattern_gen.behav_to_pat"][["instr", "status"]]
seal5_passes_status_df = seal5_status_compact_df[["instr", "status"]]
# print("seal5_passes_status_df", seal5_passes_status_df)
for instr_name in seal5_status_df["instr"].unique():
    # print("instr_name", instr_name)
    passes_status = seal5_passes_status_df[seal5_passes_status_df["instr"] == instr_name]
    assert len(passes_status) == 1
    passes_status = passes_status["status"].iloc[0]
    passes_score = 1.0 if passes_status == "good" else (0.5 if passes_status == "ok" else 0.0)
    
    pattern_gen_status = seal5_pattern_gen_status_df[seal5_pattern_gen_status_df["instr"] == instr_name]
    assert len(pattern_gen_status) == 1
    pattern_gen_status = pattern_gen_status["status"].iloc[0]
    # print("pattern_gen_status", pattern_gen_status)
    pattern_gen_score = 1.0 if pattern_gen_status == "success" else -1.0
    # print("pattern_gen_score", pattern_gen_score)
    
    new = {"instr": instr_name, "pattern_gen_score": pattern_gen_score, "passes_score": passes_score}
    seal5_score_data.append(new)
    
def calc_seal5_score(x):
    return x.min()

seal5_score_df = pd.DataFrame(seal5_score_data)
seal5_score_df["seal5_score"] =  seal5_score_df[["pattern_gen_score", "passes_score"]].apply(calc_seal5_score, axis=1)
seal5_score_df
# TODO: write to file
# Out:
#        instr  pattern_gen_score  passes_score  seal5_score
# 0    CUSTOM0                1.0           1.0          1.0
# 1    CUSTOM1                1.0           1.0          1.0
# 2    CUSTOM2                1.0           1.0          1.0
# 3    CUSTOM3                1.0           1.0          1.0
# 4    CUSTOM4                1.0           1.0          1.0
# 5    CUSTOM5                1.0           1.0          1.0
# 6    CUSTOM6                1.0           1.0          1.0
# 7    CUSTOM7                1.0           1.0          1.0
# 8    CUSTOM8                1.0           1.0          1.0
# 9    CUSTOM9                1.0           1.0          1.0
# 10  CUSTOM10                1.0           1.0          1.0
# 11  CUSTOM11                1.0           1.0          1.0
# 12  CUSTOM12                1.0           1.0          1.0

# %% [markdown]
# ## ISS Evaluation

# %%
RUN_COMPARE = Path(str(RUN) + "_compare")
REPORT_COMPARE = RUN_COMPARE / "report.csv"

COLS = ["Model", "Arch", "Run Instructions", "Run Instructions (rel.)"]
bench_compare_df = pd.read_csv(REPORT_COMPARE)[COLS]
bench_compare_df
# Out:
#         Model             Arch  Run Instructions  Run Instructions (rel.)
# 0  nettle-aes         rv32imfd           3573210                 1.000000
# 1  nettle-aes  rv32imfd_xisaac           2654136                 0.742788

# %%
#TEMP
RUN_COMPARE = Path(str(RUN) + "_compare")
REPORT_COMPARE = RUN_COMPARE / "report.csv"

COLS = ["Model", "Arch", "Run Instructions", "Run Instructions (rel.)"]
bench_compare_df = pd.read_csv(REPORT_COMPARE)[COLS]
bench_compare_df
# Out:
#         Model             Arch  Run Instructions  Run Instructions (rel.)
# 0  nettle-aes         rv32imfd           3573210                 1.000000
# 1  nettle-aes  rv32imfd_xisaac           2654136                 0.742788

# %%
RUN_COMPARE_MEM = Path(str(RUN) + "_compare_mem")
REPORT_COMPARE_MEM = RUN_COMPARE_MEM / "report.csv"

COLS = ["Model", "Arch", "Total ROM", "Total RAM", "ROM code", "ROM code (rel.)"]
bench_compare_mem_df = pd.read_csv(REPORT_COMPARE_MEM)[COLS]
bench_compare_mem_df
# Out:
#         Model             Arch  Total ROM  Total RAM  ROM code  \
# 0  nettle-aes         rv32imfd      15956       2744      6140
# 1  nettle-aes  rv32imfd_xisaac      15840       2744      6024
#
#    ROM code (rel.)
# 0         1.000000
# 1         0.981107

# %%
# temp
RUN_COMPARE_MEM = Path(str(RUN) + "_compare_mem")
REPORT_COMPARE_MEM = RUN_COMPARE_MEM / "report.csv"

COLS = ["Model", "Arch", "Total ROM", "Total RAM", "ROM code", "ROM code (rel.)"]
bench_compare_mem_df = pd.read_csv(REPORT_COMPARE_MEM)[COLS]
bench_compare_mem_df
# Out:
#         Model             Arch  Total ROM  Total RAM  ROM code  \
# 0  nettle-aes         rv32imfd      15956       2744      6140
# 1  nettle-aes  rv32imfd_xisaac      15840       2744      6024
#
#    ROM code (rel.)
# 0         1.000000
# 1         0.981107

# %% [markdown]
# ### MLonMCU Score (Set)

# %%
assert len(bench_compare_df) == 2
run_instrs_rel = bench_compare_df["Run Instructions (rel.)"].iloc[-1]
assert len(bench_compare_mem_df) == 2
rom_code_rel = bench_compare_mem_df["ROM code (rel.)"].iloc[-1]

run_instrs_score = 1.0/run_instrs_rel-1
rom_code_score = 1.0/rom_code_rel-1

# TODO: cycles!

RUN_INSTR_WEIGHT_POS = 2
ROM_CODE_WEIGHT_POS = 1
RUN_INSTR_WEIGTH_NEG = 10
ROM_CODE_WEIGHT_NEG = 2

mlonmcu_set_score_data = [{"set": "XIsaac", "run_instrs_score": run_instrs_score, "rom_code_score": rom_code_score}]

def calc_mlonmcu_score(x):
    # return gmean([x["run_instrs_score"], x["rom_code_score"]], weights=[RUN_INSTR_WEIGHT, ROM_CODE_WEIGHT])
    a = x["run_instrs_score"]
    a = a * RUN_INSTR_WEIGHT_POS if a > 0 else a * RUN_INSTR_WEIGTH_NEG
    print(a)
    b = x["rom_code_score"]
    b = b * ROM_CODE_WEIGHT_POS if b > 0 else b * ROM_CODE_WEIGHT_NEG
    print(b)
    temp = a + b
    return max(-1.0, min(1.0, temp))

mlonmcu_set_score_df = pd.DataFrame(mlonmcu_set_score_data)
mlonmcu_set_score_df["mlonmcu_score"] =  mlonmcu_set_score_df[["run_instrs_score", "rom_code_score"]].apply(calc_mlonmcu_score, axis=1)
mlonmcu_set_score_df
# TODO: write to file
# Out:
# 0.6925598386819667
# 0.019256308100929598
#       set  run_instrs_score  rom_code_score  mlonmcu_score
# 0  XIsaac           0.34628        0.019256       0.711816

# %% [markdown]
# ## Dynamic Analysis

# %%
SESS_NEW = DATE_DIR / "sess_new"
PLOTS_DIR_NEW = SESS_NEW / "plots"

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_llvm_bb.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/runtime_per_llvm_bb.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_func.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/runtime_per_func.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_opcode.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/runtime_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(PLOTS_DIR_NEW / "runtime_per_instr.jpg", 700, 350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/runtime_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
opcodes_hist_file = SESS_NEW / "table" / "opcodes_hist.pkl"
opcodes_hist_df = pd.read_pickle(opcodes_hist_file)
print("All opcodes:")
display(opcodes_hist_df)
print("Custom only:")
display(opcodes_hist_df[opcodes_hist_df["opcode"].apply(lambda x: "custom" in x)])
# Out:
# All opcodes:
#                    opcode   count  rel_count
# 0                    LOAD  822071   0.307636
# 1                      OP  711326   0.266193
# 2          custom-3/rv128  535395   0.200356
# 3                  OP-IMM  455728   0.170543
# 4                  BRANCH   69765   0.026108
# 5                   STORE   63971   0.023939
# 6                     JAL    4532   0.001696
# 7     OP-IMM (Compressed)    2175   0.000814
# 8       JALR (Compressed)    1899   0.000711
# 9      STORE (Compressed)    1649   0.000617
# 10      LOAD (Compressed)    1221   0.000457
# 11    BRANCH (Compressed)     747   0.000280
# 12                    LUI     607   0.000227
# 13                   JALR     424   0.000159
# 14  MISC-ALU (Compressed)     327   0.000122
# 15       JAL (Compressed)     317   0.000119
# 16                 SYSTEM      55   0.000021
# 17                  AUIPC      11   0.000004
# Custom only:
#            opcode   count  rel_count
# 2  custom-3/rv128  535395   0.200356

# %%
instrs_hist_file = SESS_NEW / "table" / "instrs_hist.pkl"
instrs_hist_df = pd.read_pickle(instrs_hist_file)
print("All instructions:")
display(instrs_hist_df)
print("Custom only:")
custom_instrs_hist_df = instrs_hist_df[instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(custom_instrs_hist_df)
# Out:
# All instructions:
#        instr   count     rel_count
# 0         lw  726360  2.718189e-01
# 1        xor  561020  2.099453e-01
# 2       andi  146377  5.477730e-02
# 3    custom1  133851  5.008981e-02
# 4   custom11  133848  5.008869e-02
# ..       ...     ...           ...
# 63       ori      11  4.116428e-06
# 64     auipc      11  4.116428e-06
# 65     csrai       6  2.245324e-06
# 66       sll       2  7.484414e-07
# 67     csrrw       1  3.742207e-07
#
# [68 rows x 3 columns]
# Custom only:
#       instr   count  rel_count
# 3   custom1  133851   0.050090
# 4  custom11  133848   0.050089
# 5   custom2  133848   0.050089
# 6   custom7  133848   0.050089

# %%
# temp
instrs_hist_file = SESS_NEW / "table" / "instrs_hist.pkl"
instrs_hist_df = pd.read_pickle(instrs_hist_file)
print("All instructions:")
display(instrs_hist_df)
print("Custom only:")
custom_instrs_hist_df = instrs_hist_df[instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(custom_instrs_hist_df)

# %%
dyn_counts_score_data = []

merged_custom_instrs_hist_df = pd.merge(names_df, custom_instrs_hist_df, how="outer", left_on="instr_lower", right_on="instr", suffixes=('', '_y'))

COUNT_WEIGHT = 1
CUSTOM_COUNT_WEIGHT = 1

instr_count_sum = instrs_hist_df["count"].sum()
instr_count_max = instrs_hist_df["count"].max()
print("instr_count", instr_count_sum, instr_count_max)
custom_count_sum = merged_custom_instrs_hist_df["count"].sum()
custom_count_max = merged_custom_instrs_hist_df["count"].max()
print("custom_count", custom_count_sum, custom_count_max)

for _, row_df in merged_custom_instrs_hist_df.iterrows():
    instr = row_df["instr"]
    count = row_df["count"]
    # rel_count = row_df["rel_count"]
    used = count > 0
    used_score = 1.0 if used else -1.0
    count_score = count/instr_count_max if used else -1.0
    custom_count_score = count/custom_count_max if used else -1.0
    new = {"instr": instr, "used_score": used_score, "count_score": count_score, "custom_count_score": custom_count_score}
    dyn_counts_score_data.append(new)

dyn_counts_score_df = pd.DataFrame(dyn_counts_score_data)
dyn_counts_score_df
# TODO: write to file

# %% [markdown]
# ## Static Analysis

# %% [markdown]
# ### Instructions

# %%
disass_instrs_hist_file = SESS_NEW / "table" / "disass_instrs_hist.pkl"
disass_instrs_hist_df = pd.read_pickle(disass_instrs_hist_file)
print("All instructions:")
display(disass_instrs_hist_df)
print("Custom only:")
diass_custom_instrs_hist_df = disass_instrs_hist_df[disass_instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(diass_custom_instrs_hist_df)
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_instr.jpg", 700, 350))
# Out:
# All instructions:
#         instr  count  rel_count
# 0          sw   2233   0.144634
# 1          lw   2201   0.142561
# 2        addi   1623   0.105123
# 3          li   1151   0.074551
# 4          mv   1120   0.072544
# ..        ...    ...        ...
# 83  rdinstret      1   0.000065
# 84    rdcycle      1   0.000065
# 85       divu      1   0.000065
# 86     fneg.d      1   0.000065
# 87       mret      1   0.000065
#
# [88 rows x 3 columns]
# Custom only:
#        instr  count  rel_count
# 52   custom1     11   0.000712
# 55   custom7      9   0.000583
# 54  custom11      9   0.000583
# 53   custom2      9   0.000583
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/disass_counts_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# temp
disass_instrs_hist_file = SESS_NEW / "table" / "disass_instrs_hist.pkl"
disass_instrs_hist_df = pd.read_pickle(disass_instrs_hist_file)
print("All instructions:")
display(disass_instrs_hist_df)
print("Custom only:")
diass_custom_instrs_hist_df = disass_instrs_hist_df[disass_instrs_hist_df["instr"].apply(lambda x: "custom" in x)]
display(diass_custom_instrs_hist_df)
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_instr.jpg", 700, 350))
# Out:
# All instructions:
#         instr  count  rel_count
# 0          sw   2233   0.144634
# 1          lw   2201   0.142561
# 2        addi   1623   0.105123
# 3          li   1151   0.074551
# 4          mv   1120   0.072544
# ..        ...    ...        ...
# 83  rdinstret      1   0.000065
# 84    rdcycle      1   0.000065
# 85       divu      1   0.000065
# 86     fneg.d      1   0.000065
# 87       mret      1   0.000065
#
# [88 rows x 3 columns]
# Custom only:
#        instr  count  rel_count
# 52   custom1     11   0.000712
# 55   custom7      9   0.000583
# 54  custom11      9   0.000583
# 53   custom2      9   0.000583
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/disass_counts_per_instr.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
static_counts_score_data = []

merged_diass_custom_instrs_hist_df = pd.merge(names_df, diass_custom_instrs_hist_df, how="outer", left_on="instr_lower", right_on="instr", suffixes=('', '_y'))

COUNT_WEIGHT = 1
CUSTOM_COUNT_WEIGHT = 1

instr_count_sum = disass_instrs_hist_df["count"].sum()
instr_count_max = disass_instrs_hist_df["count"].max()
# print("instr_count", instr_count_sum, instr_count_max)
custom_count_sum = merged_diass_custom_instrs_hist_df["count"].sum()
custom_count_max = merged_diass_custom_instrs_hist_df["count"].max()
# print("custom_count", custom_count_sum, custom_count_max)

for _, row_df in merged_diass_custom_instrs_hist_df.iterrows():
    instr = row_df["instr"]
    count = row_df["count"]
    # rel_count = row_df["rel_count"]
    used = count > 0
    used_score = 1.0 if used else -1.0
    count_score = count/instr_count_max if used else -1.0
    custom_count_score = count/custom_count_max if used else -1.0
    new = {"instr": instr, "used_score": used_score, "count_score": count_score, "custom_count_score": custom_count_score}
    static_counts_score_data.append(new)

static_counts_score_df = pd.DataFrame(static_counts_score_data)
static_counts_score_df
# TODO: write to file
# Out:
#        instr  used_score  count_score  custom_count_score
# 0    CUSTOM0        -1.0    -1.000000           -1.000000
# 1    CUSTOM1         1.0     0.004926            1.000000
# 2    CUSTOM2         1.0     0.004030            0.818182
# 3    CUSTOM3        -1.0    -1.000000           -1.000000
# 4    CUSTOM4        -1.0    -1.000000           -1.000000
# 5    CUSTOM5        -1.0    -1.000000           -1.000000
# 6    CUSTOM6        -1.0    -1.000000           -1.000000
# 7    CUSTOM7         1.0     0.004030            0.818182
# 8    CUSTOM8        -1.0    -1.000000           -1.000000
# 9    CUSTOM9        -1.0    -1.000000           -1.000000
# 10  CUSTOM10        -1.0    -1.000000           -1.000000
# 11  CUSTOM11         1.0     0.004030            0.818182
# 12  CUSTOM12        -1.0    -1.000000           -1.000000

# %% [markdown]
# ### Opcodes

# %%
disass_opcodes_hist_file = SESS_NEW / "table" / "disass_opcodes_hist.pkl"
disass_opcodes_hist_df = pd.read_pickle(disass_opcodes_hist_file)
print("All instructions:")
display(disass_opcodes_hist_df)
print("Custom only:")
display(disass_opcodes_hist_df[disass_opcodes_hist_df["opcode"].apply(lambda x: "custom" in x)])
print("Pie:")
display(IFrame(PLOTS_DIR_NEW / "disass_counts_per_opcode.jpg", 700, 350))
# Out:
# All instructions:
#                    opcode  count  rel_count
# 0     OP-IMM (Compressed)   2216   0.143533
# 1                  OP-IMM   1843   0.119373
# 2      STORE (Compressed)   1709   0.110694
# 3       JALR (Compressed)   1690   0.109463
# 4       LOAD (Compressed)   1643   0.106419
# 5                  BRANCH   1252   0.081093
# 6                      OP   1118   0.072414
# 7                    LOAD    827   0.053566
# 8                   STORE    699   0.045275
# 9        JAL (Compressed)    656   0.042490
# 10  MISC-ALU (Compressed)    440   0.028499
# 11    BRANCH (Compressed)    423   0.027398
# 12                    JAL    408   0.026427
# 13                    LUI    283   0.018330
# 14                  OP-FP     63   0.004081
# 15                 SYSTEM     43   0.002785
# 16         custom-3/rv128     38   0.002461
# 17                LOAD-FP     24   0.001555
# 18                   JALR     23   0.001490
# 19   LOAD-FP (Compressed)     18   0.001166
# 20                  AUIPC      8   0.000518
# 21  STORE-FP (Compressed)      7   0.000453
# 22                   MADD      6   0.000389
# 23                  MNSUB      2   0.000130
# Custom only:
#             opcode  count  rel_count
# 16  custom-3/rv128     38   0.002461
# Pie:
#         <iframe
#             width="700"
#             height="350"
#             src="../out/nettle-aes/20241202T160512/sess_new/plots/disass_counts_per_opcode.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# TODO: write utilization to file

# %%
PLOTS_DIR_NEW / "disass_counts_per_opcode.jpg"

# %% [markdown]
# ## HLS Metrics

# %%
hls_metrics_csv = WORK / "docker" / "hls" / "hls_metrics.csv"
display(pd.read_csv(hls_metrics_csv))
# Out:
#    instruction                              mask  \
# 0      CUSTOM0  0000000----------000-----1111011
# 1      CUSTOM1  0000001----------000-----1111011
# 2      CUSTOM2  0000010----------000-----1111011
# 3      CUSTOM3  000001100000-----000-----1111011
# 4      CUSTOM4  000010000000-----000-----1111011
# 5      CUSTOM5  000010100000-----000-----1111011
# 6      CUSTOM6  000011000000-----000-----1111011
# 7      CUSTOM7  0000111----------000-----1111011
# 8      CUSTOM8  0001000----------000-----1111011
# 9      CUSTOM9  0001001----------000-----1111011
# 10    CUSTOM10  0001010----------000-----1111011
# 11    CUSTOM11  0001011----------000-----1111011
# 12    CUSTOM12  0001100----------000-----1111011
# 13         NaN                               NaN
#
#                                                  tags  \
# 0   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 1   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 2   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 3   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 4   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 5   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 6   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 7   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 8   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 9   ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 10  ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 11  ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 12  ['RdStallFlush-Is-Per-ISAX', 'ReadResults-Are-...
# 13                                                NaN
#
#                                              schedule  latency   locs
# 0   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 1   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 2   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 3   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 4   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 5   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 6   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 7   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 8   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 9   [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 10  [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 11  [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 12  [{'interface': 'RdRS1', 'stage': 2}, {'interfa...      3.0    NaN
# 13                                                NaN      NaN  434.0

# %% [markdown]
# ## HW Synthesis Metrics

# %%
syn_best_csv = WORK / "docker" / "hls" / "syn_dir" / "best.csv"
display(pd.read_csv(syn_best_csv))

# %%
syn_metrics_csv = WORK / "docker" / "hls" / "syn_metrics.csv"
display(pd.read_csv(syn_metrics_csv))
# TODO: store baseline (without ext)!

# %%
# TODO: performance estimator?

# %% [markdown]
# ## LOCs Overview

# %%
from locs_helper import get_combined_locs_df
get_combined_locs_df(seal5_diff_csv=seal5_diff_csv, etiss_patch_stat="../out/nettle-aes/20241202T160512/work/docker/etiss_patch.stat", hls_metrics_csv=hls_metrics_csv)
# Out:
#     step  n_files_changed  n_insertions  n_deletions
# 0  seal5               32         728.0            0
# 1  etiss                1         986.0            0
# 2    rtl                1         434.0            0
